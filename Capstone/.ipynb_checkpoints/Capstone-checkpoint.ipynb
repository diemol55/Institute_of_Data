# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
import os

# %%
# import data
df = pd.read_csv('Data/Stock_Movements.csv', parse_dates=['TransactionDate'], index_col='TransactionDate', infer_datetime_format=True, dayfirst=True, encoding='cp1252')
df.head()
# Out:
#                  StockID        Part                      StockDescription  \
# TransactionDate
# 2020-07-31          4283  10I-SERIES                                   NaN
# 2020-09-15          4283  10I-SERIES                                   NaN
# 2021-04-12          4581  AIR-CPM-20                1/4" Male Swivel Joint
# 2021-05-25          4615  AIR-CSW-02  Universal Swivel Joint - Block Style
# 2020-07-06             1  AIR-R420FC            1/4" Female Coupler R420FC
#
#                  TransactionID  SourceTypeID        SourceType  SourceID  \
# TransactionDate
# 2020-07-31                5070            29  Supplier Invoice       132
# 2020-09-15                7726            21  Customer Invoice      4244
# 2021-04-12               21036            29  Supplier Invoice      1644
# 2021-05-25               23825            29  Supplier Invoice      1759
# 2020-07-06                2513            29  Supplier Invoice         2
#
#                 Reference       Detail   Qty    Cost  CostEach  Amount  \
# TransactionDate
# 2020-07-31        OT30016          104   1.0  942.85    942.85     0.0
# 2020-09-15        OT45431      N046749  -1.0 -942.85    942.85  1450.0
# 2021-04-12        OT30175  VTIV0004975   5.0   57.85     11.57     0.0
# 2021-05-25        OT30205  VITV0005582   2.0   23.74     11.87     0.0
# 2020-07-06        OT30001  VTIV0001018  25.0  145.00      5.80     0.0
#
#                  New Total Qty  DocumentID                          Contact
# TransactionDate
# 2020-07-31                 1.0        27.0  Automotive Test Solutions - ATS
# 2020-09-15                 0.0      1498.0                     Wittaya Mala
# 2021-04-12                 5.0       198.0                       TENG TOOLS
# 2021-05-25                 2.0       228.0                       TENG TOOLS
# 2020-07-06                32.0         1.0                       TENG TOOLS

# %%
# drop rows with part numbers ending with "-R" in Part Column - These are rental parts which are not in the scope of the project
df = df[df.Part.str.contains('-R') == False]
# drop rows with "FREIGHT" and "NETO FREIGHT" in Part Column - Not needed for this project
df = df[df.Part.str.contains('FREIGHT') == False]
df = df[df.Part.str.contains('NETO FREIGHT') == False]

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15592 entries, 2020-07-31 to 2021-06-30
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   StockID           15592 non-null  int64
#  1   Part              15592 non-null  object
#  2   StockDescription  15286 non-null  object
#  3   TransactionID     15592 non-null  int64
#  4   SourceTypeID      15592 non-null  int64
#  5   SourceType        15592 non-null  object
#  6   SourceID          15592 non-null  int64
#  7   Reference         15592 non-null  object
#  8   Detail            11896 non-null  object
#  9   Qty               15592 non-null  float64
#  10  Cost              15590 non-null  float64
#  11  CostEach          15590 non-null  float64
#  12  Amount            15592 non-null  float64
#  13  New Total Qty     14414 non-null  float64
#  14  DocumentID        13934 non-null  float64
#  15  Contact           15003 non-null  object
# dtypes: float64(6), int64(4), object(6)
# memory usage: 2.0+ MB

# %%
# create new dataset subseting df by SourceTypeID 21 and 200  - These two codes are for Qty sold and Qty returned due to credits
df_pur = df.loc[(df['SourceTypeID'] == 21) | (df['SourceTypeID'] == 200)]
df_pur.head()
# Out:
#                  StockID        Part            StockDescription  \
# TransactionDate
# 2020-09-15          4283  10I-SERIES                         NaN
# 2021-07-05          3465  ATE-FB30SR  ATE Brake Bleeding Machine
# 2021-02-05          4279     BOR2000        iC Inspection Camera
# 2021-03-11          4279     BOR2000        iC Inspection Camera
# 2021-10-13          4279     BOR2000        iC Inspection Camera
#
#                  TransactionID  SourceTypeID        SourceType  SourceID  \
# TransactionDate
# 2020-09-15                7726            21  Customer Invoice      4244
# 2021-07-05               26760            21  Customer Invoice     22242
# 2021-02-05               15659            21  Customer Invoice     12223
# 2021-03-11               17884            21  Customer Invoice     12998
# 2021-10-13               33400            21  Customer Invoice     28921
#
#                 Reference    Detail  Qty       Cost   CostEach   Amount  \
# TransactionDate
# 2020-09-15        OT45431   N046749 -1.0  -942.8500   942.8500  1450.00
# 2021-07-05        OT52362  35S60333 -1.0 -2000.0000  2000.0000  2510.00
# 2021-02-05        OT48398   N048864 -1.0 -1508.9082  1508.9082  2195.00
# 2021-03-11        OT49304       NaN -1.0 -1508.9082  1508.9082  2195.00
# 2021-10-13        OT55171       NaN -1.0 -1302.7210  1302.7210  2295.45
#
#                  New Total Qty  DocumentID         Contact
# TransactionDate
# 2020-09-15                 0.0      1498.0    Wittaya Mala
# 2021-07-05                 0.0      9101.0           Manny
# 2021-02-05                 1.0      4940.0       Hud Cavka
# 2021-03-11                 0.0      5264.0  Jason Robinson
# 2021-10-13                 1.0     12052.0     Leif Coplin

# %%
# info about the data
df_pur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11912 entries, 2020-09-15 to 2020-07-28
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   StockID           11912 non-null  int64
#  1   Part              11912 non-null  object
#  2   StockDescription  11780 non-null  object
#  3   TransactionID     11912 non-null  int64
#  4   SourceTypeID      11912 non-null  int64
#  5   SourceType        11912 non-null  object
#  6   SourceID          11912 non-null  int64
#  7   Reference         11912 non-null  object
#  8   Detail            8683 non-null   object
#  9   Qty               11912 non-null  float64
#  10  Cost              11912 non-null  float64
#  11  CostEach          11912 non-null  float64
#  12  Amount            11912 non-null  float64
#  13  New Total Qty     11284 non-null  float64
#  14  DocumentID        11892 non-null  float64
#  15  Contact           11892 non-null  object
# dtypes: float64(6), int64(4), object(6)
# memory usage: 1.5+ MB

# %%
# resample the data to daily frequency and sum the columns
df_pur_daily = df_pur.resample('D').sum()
df_pur_daily.head()
# Out:
#                  StockID  TransactionID  SourceTypeID  SourceID  Qty   Cost  \
# TransactionDate
# 2020-07-01           859           2372           200      2371  1.0  11.06
# 2020-07-02             0              0             0         0  0.0   0.00
# 2020-07-03          6398          10147            84       382 -4.0 -93.38
# 2020-07-04             0              0             0         0  0.0   0.00
# 2020-07-05             0              0             0         0  0.0   0.00
#
#                  CostEach  Amount  New Total Qty  DocumentID
# TransactionDate
# 2020-07-01          11.06  -47.00            4.0         0.0
# 2020-07-02           0.00    0.00            0.0         0.0
# 2020-07-03          93.38  313.18           18.0       158.0
# 2020-07-04           0.00    0.00            0.0         0.0
# 2020-07-05           0.00    0.00            0.0         0.0

# %%
# mulyiply the Qty column by -1 to get the net movement
df_pur_daily['Qty'] = df_pur_daily['Qty'] * -1

# %%
# drop last row - las row dropped since it was just the first day of the month
df_pur_daily = df_pur_daily.drop(df_pur_daily.tail(1).index)

# %%
# display the first 5 rows of the dataframe
df_pur_daily.head()
# Out:
#                  StockID  TransactionID  SourceTypeID  SourceID  Qty   Cost  \
# TransactionDate
# 2020-07-01           859           2372           200      2371 -1.0  11.06
# 2020-07-02             0              0             0         0 -0.0   0.00
# 2020-07-03          6398          10147            84       382  4.0 -93.38
# 2020-07-04             0              0             0         0 -0.0   0.00
# 2020-07-05             0              0             0         0 -0.0   0.00
#
#                  CostEach  Amount  New Total Qty  DocumentID
# TransactionDate
# 2020-07-01          11.06  -47.00            4.0         0.0
# 2020-07-02           0.00    0.00            0.0         0.0
# 2020-07-03          93.38  313.18           18.0       158.0
# 2020-07-04           0.00    0.00            0.0         0.0
# 2020-07-05           0.00    0.00            0.0         0.0

# %%
# plot Qty on a daily basis - this is the daily movement of the inventory including weekends and holidays
df_pur_daily['Qty'].plot(figsize=(12, 6))
plt.show()

# %%
# plot Qty on a weekly basis
df_pur_daily['Qty'].resample('W').sum().plot(figsize=(12, 6))
plt.show()

# %%
# plot amount on a daily basis - this is the daily income on sales
df_pur_daily['Amount'].plot(figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='TransactionDate'>

# %%
# plot qty on a monthly basis
df_pur_daily['Qty'].resample('M').sum().plot(figsize=(12, 6))
plt.show()

# %%
# dataset tail
df_pur_daily.tail()
# Out:
#                  StockID  TransactionID  SourceTypeID  SourceID   Qty  \
# TransactionDate
# 2021-10-27         31635         718885           441    625172  22.0
# 2021-10-28         82061        1270381           956   1108924  40.0
# 2021-10-29         68559        1584214          1145   1379614  59.0
# 2021-10-30             0              0             0         0  -0.0
# 2021-10-31             0              0             0         0  -0.0
#
#                       Cost   CostEach   Amount  New Total Qty  DocumentID
# TransactionDate
# 2021-10-27      -1939.6887  1933.4684  3357.01          297.0    261196.0
# 2021-10-28      -1139.9846  1247.7051  1718.37          488.0    461557.0
# 2021-10-29      -1875.0100  1786.7406  2919.00          628.0    574717.0
# 2021-10-30          0.0000     0.0000     0.00            0.0         0.0
# 2021-10-31          0.0000     0.0000     0.00            0.0         0.0

# %%
# Create a new column with month name and year - this is used to group the data by month and plot the data
df_pur_daily['Month'] = df_pur_daily.index.to_period('M')
df_pur_daily.head()
# Out:
#                  StockID  TransactionID  SourceTypeID  SourceID  Qty   Cost  \
# TransactionDate
# 2020-07-01           859           2372           200      2371 -1.0  11.06
# 2020-07-02             0              0             0         0 -0.0   0.00
# 2020-07-03          6398          10147            84       382  4.0 -93.38
# 2020-07-04             0              0             0         0 -0.0   0.00
# 2020-07-05             0              0             0         0 -0.0   0.00
#
#                  CostEach  Amount  New Total Qty  DocumentID    Month
# TransactionDate
# 2020-07-01          11.06  -47.00            4.0         0.0  2020-07
# 2020-07-02           0.00    0.00            0.0         0.0  2020-07
# 2020-07-03          93.38  313.18           18.0       158.0  2020-07
# 2020-07-04           0.00    0.00            0.0         0.0  2020-07
# 2020-07-05           0.00    0.00            0.0         0.0  2020-07

# %%
# boxplot of Qty by month seaborn
sns.boxplot(x='Month', y='Qty', data=df_pur_daily, palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
# create new dataframe with data from Aug 2020 to Oct 31 2021 - we decided to drop the first month data since a new system was implemented and the data wasn't consistent
df_pur_daily_2020 = df_pur_daily.loc['2020-08-01':'2021-10-31']
df_pur_daily_2020.head()
# Out:
#                  StockID  TransactionID  SourceTypeID  SourceID   Qty  \
# TransactionDate
# 2020-08-01             0              0             0         0  -0.0
# 2020-08-02             0              0             0         0  -0.0
# 2020-08-03         47250         169277           777     94861  38.0
# 2020-08-04         54858         255501          2208    158236  44.0
# 2020-08-05         61756         210211          1082    116976  42.0
#
#                       Cost   CostEach   Amount  New Total Qty  DocumentID  \
# TransactionDate
# 2020-08-01          0.0000     0.0000     0.00            0.0         0.0
# 2020-08-02          0.0000     0.0000     0.00            0.0         0.0
# 2020-08-03      -1190.1300  1180.9300  3118.16          453.0     31961.0
# 2020-08-04      -1503.5200  1557.2200  4207.88          489.0     49362.0
# 2020-08-05      -3333.1057  5478.3357  6449.84          347.0     38749.0
#
#                    Month
# TransactionDate
# 2020-08-01       2020-08
# 2020-08-02       2020-08
# 2020-08-03       2020-08
# 2020-08-04       2020-08
# 2020-08-05       2020-08

# %%
# plot qty on a daily basis
df_pur_daily_2020['Qty'].plot(figsize=(12, 6)) 
plt.show()

# %%
# plot qty on a weekly basis
df_pur_daily_2020['Qty'].resample('W').sum().plot(figsize=(12, 6))
plt.show()

# %%
# plot qty on a monthly basis
df_pur_daily_2020['Qty'].resample('M').sum().plot(figsize=(12, 6))
plt.show()

# %%
# boxplot of Qty by month seaborn
sns.boxplot(x='Month', y='Qty', data=df_pur_daily_2020, palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
# plot a histogram of Qty for March 2021
df_pur_daily_2020['Qty'].loc['2021-03-01':'2021-03-31'].plot(kind='hist')
plt.show()

# %%
# We decided to drop the first month since a new system was implemented and the data was not accurate
# We also decided to drop weekends it will creat a lot of noise
df_pur_daily_2020 = df_pur_daily_2020.drop(df_pur_daily_2020[df_pur_daily_2020['Qty'] == 0].index)

# %%
# boxplot of Qty by month with weekends dropped
sns.boxplot(x='Month', y='Qty', data=df_pur_daily_2020, palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
# plot a histogram of Qty for March 2021 with weekends dropped
df_pur_daily_2020['Qty'].loc['2021-03-01':'2021-03-31'].plot(kind='hist')
plt.show()

# %%
# plot Qty on a daily basis
df_pur_daily_2020['Qty'].plot(figsize=(12, 6))
plt.show()

# %%
# plot Qty on a weekly basis
df_pur_daily_2020['Qty'].resample('W').sum().plot(figsize=(12, 6))
plt.show()

# %%
# import data
# we created a time series with special sales for 2020 and 2021 to input as a signal
df_flyers = pd.read_csv('Data/Flyers_Signals.csv', parse_dates=['Date'], index_col='Date', infer_datetime_format=True, dayfirst=True)
df_flyers.head()
# Out:
#             Ozwide Flyer  Hsy Flyer
# Date
# 2020-07-01             0          1
# 2020-07-02             0          1
# 2020-07-03             0          1
# 2020-07-04             0          0
# 2020-07-05             0          0

# %%
# plot df_flyers
df_flyers.plot(figsize=(12, 6))
plt.show()

# %%
# join df_pur_daily_2020 and df_flyers on the index - new dataset including the flyers signal
df_pur_daily_2020_flyers = df_pur_daily_2020.join(df_flyers, how='inner')
df_pur_daily_2020_flyers.head(10)
# Out:
#             StockID  TransactionID  SourceTypeID  SourceID   Qty       Cost  \
# 2020-08-03    47250         169277           777     94861  38.0 -1190.1300
# 2020-08-04    54858         255501          2208    158236  44.0 -1503.5200
# 2020-08-05    61756         210211          1082    116976  42.0 -3333.1057
# 2020-08-06    48940         183010          1314    111223  33.0 -1590.1800
# 2020-08-07    16091          60290           431     37660  10.0 -1116.5300
# 2020-08-10    39879         159346           830     96700  28.0  -920.9050
# 2020-08-11    20926          89053           357     53570  20.0  -761.3500
# 2020-08-12    65806         159903           630     95649  31.0 -2124.5900
# 2020-08-13    45564         140864           725     87941  24.0 -1260.6500
# 2020-08-14    39918         175975           672    106988  32.0  -901.9619
#
#              CostEach   Amount  New Total Qty  DocumentID    Month  \
# 2020-08-03  1180.9300  3118.16          453.0     31961.0  2020-08
# 2020-08-04  1557.2200  4207.88          489.0     49362.0  2020-08
# 2020-08-05  5478.3357  6449.84          347.0     38749.0  2020-08
# 2020-08-06  1581.9600  4544.90         1323.0     34600.0  2020-08
# 2020-08-07  1756.5300  2184.82           71.0     12145.0  2020-08
# 2020-08-10  1063.2850  2476.49          189.0     31293.0  2020-08
# 2020-08-11   685.5750  2106.37          138.0     18339.0  2020-08
# 2020-08-12  2124.5900  4251.67          185.0     32886.0  2020-08
# 2020-08-13  1272.1900  3321.48          204.0     29630.0  2020-08
# 2020-08-14   901.9619  2472.72          371.0     36958.0  2020-08
#
#             Ozwide Flyer  Hsy Flyer
# 2020-08-03             0          1
# 2020-08-04             0          1
# 2020-08-05             0          1
# 2020-08-06             0          1
# 2020-08-07             0          1
# 2020-08-10             0          0
# 2020-08-11             0          0
# 2020-08-12             0          0
# 2020-08-13             0          0
# 2020-08-14             0          0

# %%
# we created three new columns with the day, week and month of the year to pick up trends based on seasonal patterns
# create column day of the year
df_pur_daily_2020_flyers['DayOfYear'] = df_pur_daily_2020_flyers.index.dayofyear
# create column day of the week
df_pur_daily_2020_flyers['DayOfWeek'] = df_pur_daily_2020_flyers.index.dayofweek
# create column month
df_pur_daily_2020_flyers['Month'] = df_pur_daily_2020_flyers.index.month
df_pur_daily_2020_flyers.head()
# Out:
#             StockID  TransactionID  SourceTypeID  SourceID   Qty       Cost  \
# 2020-08-03    47250         169277           777     94861  38.0 -1190.1300
# 2020-08-04    54858         255501          2208    158236  44.0 -1503.5200
# 2020-08-05    61756         210211          1082    116976  42.0 -3333.1057
# 2020-08-06    48940         183010          1314    111223  33.0 -1590.1800
# 2020-08-07    16091          60290           431     37660  10.0 -1116.5300
#
#              CostEach   Amount  New Total Qty  DocumentID  Month  \
# 2020-08-03  1180.9300  3118.16          453.0     31961.0      8
# 2020-08-04  1557.2200  4207.88          489.0     49362.0      8
# 2020-08-05  5478.3357  6449.84          347.0     38749.0      8
# 2020-08-06  1581.9600  4544.90         1323.0     34600.0      8
# 2020-08-07  1756.5300  2184.82           71.0     12145.0      8
#
#             Ozwide Flyer  Hsy Flyer  DayOfYear  DayOfWeek
# 2020-08-03             0          1        216          0
# 2020-08-04             0          1        217          1
# 2020-08-05             0          1        218          2
# 2020-08-06             0          1        219          3
# 2020-08-07             0          1        220          4

# %%
# drop columns StockID, TransactionID, SourceTypeID, SourceID, Cost, CostEach, Amount, New Total Qty, DocumentID
# the result of this dataset is our dataframe with the features needed for the model
df_pur_daily_2020_flyers = df_pur_daily_2020_flyers.drop(['StockID', 'TransactionID', 'SourceTypeID', 'SourceID', 'Cost', 'CostEach', 'Amount', 'New Total Qty', 'DocumentID'], axis=1)
df_pur_daily_2020_flyers.head()
# Out:
#              Qty  Month  Ozwide Flyer  Hsy Flyer  DayOfYear  DayOfWeek
# 2020-08-03  38.0      8             0          1        216          0
# 2020-08-04  44.0      8             0          1        217          1
# 2020-08-05  42.0      8             0          1        218          2
# 2020-08-06  33.0      8             0          1        219          3
# 2020-08-07  10.0      8             0          1        220          4

# %%
# plot Qty, Hsy Flyer and Ozwide Flyer on a daily basis in different plots
fig, axs = plt.subplots(3, 1, figsize=(12, 10))
df_pur_daily_2020_flyers['Qty'].plot(ax=axs[0])
df_pur_daily_2020_flyers['Hsy Flyer'].plot(ax=axs[1])
df_pur_daily_2020_flyers['Ozwide Flyer'].plot(ax=axs[2])
fig.tight_layout(pad=2.0)
plt.show()

# %%
# target variable
target = ['Qty']
# time steps in the future
shift_moths = 1
shifth_steps = shift_moths * 30
# create a new column with the shifted values - this is the way to predict the future values based on the past values this is the method used to conver this into a supervised learning problem
df_pur_daily_2020_flyers['Qty_shift'] = df_pur_daily_2020_flyers['Qty'].shift(-shifth_steps)
df_pur_daily_2020_flyers.head()
# Out:
#              Qty  Month  Ozwide Flyer  Hsy Flyer  DayOfYear  DayOfWeek  \
# 2020-08-03  38.0      8             0          1        216          0
# 2020-08-04  44.0      8             0          1        217          1
# 2020-08-05  42.0      8             0          1        218          2
# 2020-08-06  33.0      8             0          1        219          3
# 2020-08-07  10.0      8             0          1        220          4
#
#             Qty_shift
# 2020-08-03       30.0
# 2020-08-04       45.0
# 2020-08-05       18.0
# 2020-08-06       41.0
# 2020-08-07       38.0

# %%
# check the data has been shifted in the future
df_pur_daily_2020_flyers.tail(5)
# Out:
#              Qty  Month  Ozwide Flyer  Hsy Flyer  DayOfYear  DayOfWeek  \
# 2021-10-25  42.0     10             0          0        298          0
# 2021-10-26  34.0     10             0          0        299          1
# 2021-10-27  22.0     10             0          0        300          2
# 2021-10-28  40.0     10             0          0        301          3
# 2021-10-29  59.0     10             0          0        302          4
#
#             Qty_shift
# 2021-10-25        NaN
# 2021-10-26        NaN
# 2021-10-27        NaN
# 2021-10-28        NaN
# 2021-10-29        NaN

# %%
# generate numpy array of the data
X = df_pur_daily_2020_flyers[['Qty','DayOfYear', 'DayOfWeek', 'Month', 'Hsy Flyer', 'Ozwide Flyer']].values[0:-shifth_steps]
y = df_pur_daily_2020_flyers['Qty_shift'].values[0:-shifth_steps]
print('X shape is:', X.shape)
print('y shape is:', y.shape)
# Out:
# X shape is: (290, 6)
# y shape is: (290,)

# %%
# import preprocessing and model selection libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
print('X_train shape is:', X_train.shape)
print('X_test shape is:', X_test.shape)
print('y_train shape is:', y_train.shape)
print('y_test shape is:', y_test.shape)
# Out:
# X_train shape is: (261, 6)
# X_test shape is: (29, 6)
# y_train shape is: (261,)
# y_test shape is: (29,)

# %%
# scale data
X_scaler = MinMaxScaler()
X_train_scaled = X_scaler.fit_transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# step by step approach
# # reshape data
# X_train_scaled = X_train_scaled.reshape((X_train_scaled.shape[0], 1, X_train_scaled.shape[1]))
# X_test_scaled = X_test_scaled.reshape((X_test_scaled.shape[0], 1, X_test_scaled.shape[1]))

# %%
# data shape
print('X_train_scaled shape is:', X_train_scaled.shape)
print('X_test_scaled shape is:', X_test_scaled.shape)
# Out:
# X_train_scaled shape is: (261, 6)
# X_test_scaled shape is: (29, 6)

# %%
print('Min: ', X_train_scaled.min())
print('Max: ', X_train_scaled.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# scale y data
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.reshape(-1, 1))
y_train_scaled = y_train_scaled.reshape(-1)
y_test_scaled = y_test_scaled.reshape(-1)

# %%
# step by step approach
# # reshape y data
# y_train_scaled = y_train_scaled.reshape((y_train_scaled.shape[0], 1))
# y_test_scaled = y_test_scaled.reshape((y_test_scaled.shape[0], 1))

# %%
# data shape
print('y_train_scaled shape is:', y_train_scaled.shape)
print('y_test_scaled shape is:', y_test_scaled.shape)
# Out:
# y_train_scaled shape is: (261,)
# y_test_scaled shape is: (29,)

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, 6)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (batch_size, sequence_length)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(X_train.shape[0] - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = X_train_scaled[idx:idx+sequence_length]
            y_batch[i] = y_train_scaled[idx:idx+sequence_length]
        
        yield (x_batch, y_batch)

# %%
X_batch, y_batch = next(batch_generator(batch_size=300, sequence_length=90))

# %%
print(X_batch.shape)
print(y_batch.shape)
# Out:
# (300, 90, 6)
# (300, 90)

# %%
validation_data = (X_test_scaled.reshape((1, X_test_scaled.shape[0], X_test_scaled.shape[1])), y_test_scaled.reshape((1, y_test_scaled.shape[0])))

# %%
# import RNN libraries tensoflow and keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, SimpleRNN, LSTM, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras.backend import square, mean
print('Tensorflow Version: ',tf.__version__)
print('Keras Version: ',tf.keras.__version__)
print('Numpy Version: ',np.__version__)
# Out:
# Tensorflow Version:  2.6.0
# Keras Version:  2.6.0
# Numpy Version:  1.19.5

# %%
# learning curves function
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %%
# plot predictions function
def plot_comparison(start_idx, length=100, train=True, model=None):
    """
    Plot the predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if train:
        # Use training-data.
        x = X_train_scaled
        y_true = y_train
    else:
        # Use test-data.
        x = X_test_scaled
        y_true = y_test
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    # x = np.expand_dims(x, axis=0)
    x = x.reshape((1, x.shape[0], x.shape[1]))

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    
    # For each output-signal.
    for signal in range(len(target)):
        # Get the output-signal predicted by the model.
        signal_pred = y_pred_rescaled[:]
        
        # Get the true output-signal from the data-set.
        signal_true = y_true[:]

        # Make the plotting-canvas bigger.
        plt.figure(figsize=(15,5))
        
        # Plot and compare the two signals.
        plt.plot(signal_true, label='true')
        plt.plot(signal_pred, label='pred')
        
        # Plot grey box for warmup-period.
        p = plt.axvspan(0, 5, facecolor='black', alpha=0.15)
        
        # Plot labels etc.
        plt.ylabel(target[signal])
        plt.legend()
        plt.show()
        # print sklearn mean squared error
        print('MSE:', np.sqrt(mean_squared_error(signal_true, signal_pred)))

# %%
# callback
path_checkpoint = '23_checkpoint.keras'
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint, monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True)

callback_early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

callback_tensorboard = TensorBoard(log_dir='./23_logs/', histogram_freq=0, write_graph=False)

callback_reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, min_lr=1e-4, patience=0, verbose=1)

callbacks = [callback_early_stopping,
             callback_checkpoint,
             callback_tensorboard,
             callback_reduce_lr]
# Out:
# 2021-11-07 19:42:31.100965: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2021-11-07 19:42:31.101288: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2021-11-07 19:42:31.101636: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-07 19:42:31.102317: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.

# %%
# Create the SimpleRNN model
model = Sequential()
model.add(SimpleRNN(50, return_sequences=True, input_shape=(None, 6)))
model.add(SimpleRNN(50, return_sequences=True))
model.add(Dense(1, activation='relu'))
# Out:
# 2021-11-07 19:29:39.303539: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-07 19:29:39.303664: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DiegoM): /proc/driver/nvidia/version does not exist
# 2021-11-07 19:29:39.304175: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# compile the model
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_batch, y_batch, epochs=20, validation_data=validation_data, verbose=1, steps_per_epoch=20, callbacks=callbacks)
# Out:
# 2021-11-07 19:29:42.064865: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
#  1/20 [>.............................] - ETA: 27s - loss: 0.0286
# 2021-11-07 19:29:43.598752: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2021-11-07 19:29:43.598792: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2021-11-07 19:29:43.630500: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2021-11-07 19:29:43.661892: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2021-11-07 19:29:43.721458: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_29_43
#
# 2021-11-07 19:29:43.781160: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ./23_logs/train/plugins/profile/2021_11_07_19_29_43/DiegoM.trace.json.gz
# 2021-11-07 19:29:43.800578: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_29_43
#
# 2021-11-07 19:29:43.800745: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ./23_logs/train/plugins/profile/2021_11_07_19_29_43/DiegoM.memory_profile.json.gz
# 2021-11-07 19:29:43.801681: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_29_43
# Dumped tool data for xplane.pb to ./23_logs/train/plugins/profile/2021_11_07_19_29_43/DiegoM.xplane.pb
# Dumped tool data for overview_page.pb to ./23_logs/train/plugins/profile/2021_11_07_19_29_43/DiegoM.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./23_logs/train/plugins/profile/2021_11_07_19_29_43/DiegoM.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./23_logs/train/plugins/profile/2021_11_07_19_29_43/DiegoM.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./23_logs/train/plugins/profile/2021_11_07_19_29_43/DiegoM.kernel_stats.pb
# 20/20 [==============================] - 2s 54ms/step - loss: 0.0210 - val_loss: 0.0247
#
# Epoch 00001: val_loss improved from inf to 0.02474, saving model to 23_checkpoint.keras
# Epoch 2/20
# 20/20 [==============================] - 1s 47ms/step - loss: 0.0123 - val_loss: 0.0194
#
# Epoch 00002: val_loss improved from 0.02474 to 0.01941, saving model to 23_checkpoint.keras
# Epoch 3/20
# 20/20 [==============================] - 1s 30ms/step - loss: 0.0094 - val_loss: 0.0164
#
# Epoch 00003: val_loss improved from 0.01941 to 0.01638, saving model to 23_checkpoint.keras
# Epoch 4/20
# 20/20 [==============================] - 1s 45ms/step - loss: 0.0063 - val_loss: 0.0118
#
# Epoch 00004: val_loss improved from 0.01638 to 0.01184, saving model to 23_checkpoint.keras
# Epoch 5/20
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0045 - val_loss: 0.0095
#
# Epoch 00005: val_loss improved from 0.01184 to 0.00949, saving model to 23_checkpoint.keras
# Epoch 6/20
# 20/20 [==============================] - 1s 32ms/step - loss: 0.0034 - val_loss: 0.0086
#
# Epoch 00006: val_loss improved from 0.00949 to 0.00862, saving model to 23_checkpoint.keras
# Epoch 7/20
# 20/20 [==============================] - 1s 34ms/step - loss: 0.0027 - val_loss: 0.0086
#
# Epoch 00007: val_loss improved from 0.00862 to 0.00860, saving model to 23_checkpoint.keras
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 8/20
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0024 - val_loss: 0.0087
#
# Epoch 00008: val_loss did not improve from 0.00860
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 9/20
# 20/20 [==============================] - 1s 47ms/step - loss: 0.0023 - val_loss: 0.0087
#
# Epoch 00009: val_loss did not improve from 0.00860
# Epoch 10/20
# 20/20 [==============================] - 1s 33ms/step - loss: 0.0023 - val_loss: 0.0087
#
# Epoch 00010: val_loss did not improve from 0.00860
# Epoch 11/20
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0023 - val_loss: 0.0087
#
# Epoch 00011: val_loss did not improve from 0.00860
# Epoch 12/20
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0022 - val_loss: 0.0087
#
# Epoch 00012: val_loss did not improve from 0.00860
# Epoch 00012: early stopping

# %%
# plot learning curves
plot_learning_curves(history.history['loss'], history.history['val_loss'])
plt.show()

# %%
# plot predictions train
plot_comparison(start_idx=50, length=250, train=True, model=model)
# Out:
# MSE: 12.653519852288733

# %%
# plot predictions test
plot_comparison(start_idx=0, length=20, train=False, model=model)
# Out:
# MSE: 27.03901118844139

# %%
# create LSTM model
model_LSTM = Sequential()
model_LSTM.add(LSTM(50, return_sequences=True, input_shape=(None, 6)))
model_LSTM.add(LSTM(50, return_sequences=True))
model_LSTM.add(Dense(1, activation='relu'))
# Out:
# 2021-11-07 19:36:47.171150: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-07 19:36:47.171214: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DiegoM): /proc/driver/nvidia/version does not exist
# 2021-11-07 19:36:47.171527: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# compile the model
model_LSTM.compile(optimizer='adam', loss='mse')
history_LSTM = model_LSTM.fit(X_batch, y_batch, epochs=20, validation_data=validation_data, verbose=1, steps_per_epoch=20, callbacks=callbacks)
# Out:
# 2021-11-07 19:36:49.626118: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
#  2/20 [==>...........................] - ETA: 1s - loss: 0.0116
# 2021-11-07 19:36:52.258699: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2021-11-07 19:36:52.258744: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2021-11-07 19:36:52.335765: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2021-11-07 19:36:52.389073: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
#  3/20 [===>..........................] - ETA: 3s - loss: 0.0121
# 2021-11-07 19:36:52.480301: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_36_52
#
# 2021-11-07 19:36:52.572575: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ./23_logs/train/plugins/profile/2021_11_07_19_36_52/DiegoM.trace.json.gz
# 2021-11-07 19:36:52.600794: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_36_52
#
# 2021-11-07 19:36:52.600960: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ./23_logs/train/plugins/profile/2021_11_07_19_36_52/DiegoM.memory_profile.json.gz
# 2021-11-07 19:36:52.602046: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_36_52
# Dumped tool data for xplane.pb to ./23_logs/train/plugins/profile/2021_11_07_19_36_52/DiegoM.xplane.pb
# Dumped tool data for overview_page.pb to ./23_logs/train/plugins/profile/2021_11_07_19_36_52/DiegoM.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./23_logs/train/plugins/profile/2021_11_07_19_36_52/DiegoM.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./23_logs/train/plugins/profile/2021_11_07_19_36_52/DiegoM.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./23_logs/train/plugins/profile/2021_11_07_19_36_52/DiegoM.kernel_stats.pb
# 20/20 [==============================] - 5s 126ms/step - loss: 0.0090 - val_loss: 0.0070
#
# Epoch 00001: val_loss improved from inf to 0.00696, saving model to 23_checkpoint.keras
# Epoch 2/20
# 20/20 [==============================] - 1s 56ms/step - loss: 0.0078 - val_loss: 0.0062
#
# Epoch 00002: val_loss improved from 0.00696 to 0.00615, saving model to 23_checkpoint.keras
# Epoch 3/20
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0076 - val_loss: 0.0059
#
# Epoch 00003: val_loss improved from 0.00615 to 0.00591, saving model to 23_checkpoint.keras
# Epoch 4/20
# 20/20 [==============================] - 1s 71ms/step - loss: 0.0074 - val_loss: 0.0059
#
# Epoch 00004: val_loss improved from 0.00591 to 0.00588, saving model to 23_checkpoint.keras
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/20
# 20/20 [==============================] - 1s 68ms/step - loss: 0.0073 - val_loss: 0.0059
#
# Epoch 00005: val_loss did not improve from 0.00588
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 6/20
# 20/20 [==============================] - 1s 60ms/step - loss: 0.0073 - val_loss: 0.0059
#
# Epoch 00006: val_loss did not improve from 0.00588
# Epoch 7/20
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0073 - val_loss: 0.0059
#
# Epoch 00007: val_loss did not improve from 0.00588
# Epoch 8/20
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0073 - val_loss: 0.0059
#
# Epoch 00008: val_loss did not improve from 0.00588
# Epoch 9/20
# 20/20 [==============================] - 1s 73ms/step - loss: 0.0073 - val_loss: 0.0059
#
# Epoch 00009: val_loss did not improve from 0.00588
# Epoch 00009: early stopping

# %%
model_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 50)          11400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 50)          20200
# _________________________________________________________________
# dense (Dense)                (None, None, 1)           51
# =================================================================
# Total params: 31,651
# Trainable params: 31,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot learning curves
plot_learning_curves(history_LSTM.history['loss'], history_LSTM.history['val_loss'])
plt.show()

# %%
# plot predictions train
plot_comparison(start_idx=50, length=250, train=True, model=model_LSTM)
# Out:
# MSE: 19.30676866051874

# %%
# plot predictions test
plot_comparison(start_idx=0, length=20, train=False, model=model_LSTM)
# Out:
# MSE: 18.544491806670866

# %%
# Create GRU model
model_GRU = Sequential()
model_GRU.add(GRU(units=50, return_sequences=True, input_shape=(None, 6)))
model_GRU.add(GRU(units=50, return_sequences=True))
model_GRU.add(Dense(units=1, activation='relu'))
# Out:
# 2021-11-07 19:42:47.620468: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-07 19:42:47.620525: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DiegoM): /proc/driver/nvidia/version does not exist
# 2021-11-07 19:42:47.620808: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# compile the model
model_GRU.compile(optimizer='adam', loss='mse')
history_GRU = model_GRU.fit(X_batch, y_batch, epochs=20, validation_data=validation_data, verbose=1, steps_per_epoch=20, callbacks=callbacks)
# Out:
# 2021-11-07 19:42:54.589438: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
#  2/20 [==>...........................] - ETA: 1s - loss: 0.0261
# 2021-11-07 19:42:56.946848: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2021-11-07 19:42:56.946887: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2021-11-07 19:42:57.023953: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2021-11-07 19:42:57.097462: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
#  3/20 [===>..........................] - ETA: 3s - loss: 0.0258
# 2021-11-07 19:42:57.210533: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_42_57
#
# 2021-11-07 19:42:57.293544: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ./23_logs/train/plugins/profile/2021_11_07_19_42_57/DiegoM.trace.json.gz
# 2021-11-07 19:42:57.321226: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_42_57
#
# 2021-11-07 19:42:57.321417: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ./23_logs/train/plugins/profile/2021_11_07_19_42_57/DiegoM.memory_profile.json.gz
# 2021-11-07 19:42:57.322636: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_42_57
# Dumped tool data for xplane.pb to ./23_logs/train/plugins/profile/2021_11_07_19_42_57/DiegoM.xplane.pb
# Dumped tool data for overview_page.pb to ./23_logs/train/plugins/profile/2021_11_07_19_42_57/DiegoM.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./23_logs/train/plugins/profile/2021_11_07_19_42_57/DiegoM.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./23_logs/train/plugins/profile/2021_11_07_19_42_57/DiegoM.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./23_logs/train/plugins/profile/2021_11_07_19_42_57/DiegoM.kernel_stats.pb
# 20/20 [==============================] - 4s 101ms/step - loss: 0.0249 - val_loss: 0.0275
#
# Epoch 00001: val_loss improved from inf to 0.02754, saving model to 23_checkpoint.keras
# Epoch 2/20
# 20/20 [==============================] - 1s 50ms/step - loss: 0.0249 - val_loss: 0.0275
#
# Epoch 00002: val_loss did not improve from 0.02754
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 3/20
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0249 - val_loss: 0.0275
#
# Epoch 00003: val_loss did not improve from 0.02754
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 4/20
# 20/20 [==============================] - 1s 48ms/step - loss: 0.0249 - val_loss: 0.0275
#
# Epoch 00004: val_loss did not improve from 0.02754
# Epoch 5/20
# 20/20 [==============================] - 1s 54ms/step - loss: 0.0249 - val_loss: 0.0275
#
# Epoch 00005: val_loss did not improve from 0.02754
# Epoch 6/20
# 20/20 [==============================] - 1s 65ms/step - loss: 0.0249 - val_loss: 0.0275
#
# Epoch 00006: val_loss did not improve from 0.02754
# Epoch 00006: early stopping

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20162/3470139634.py in <module>
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
# plot learning curves
plot_learning_curves(history_GRU.history["loss"], history_GRU.history["val_loss"])
plt.show()

# %%
# plot predictions train
plot_comparison(start_idx=50, length=250, train=True, model=model_GRU)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd68ff97af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MSE: 18.904457089983453

# %%
# plot predictions test
plot_comparison(start_idx=0, length=20, train=False, model=model_GRU)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd68ff97af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MSE: 15.976412706131788

# %%
# create convolutional model
model_1D = Sequential()
model_1D.add(Conv1D(filters=20, kernel_size=4, strides=2, padding='valid', input_shape=(None, 6)))
model_1D.add(GRU(units=20, return_sequences=True))
model_1D.add(GRU(units=20, return_sequences=True))
model_1D.add(GRU(units=20))
model_1D.add(Dense(units=1, activation='relu'))

# %%
# compile the model
model_1D.compile(loss='mean_squared_error', optimizer='adam')

# %%
model_1D.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, None, 20)          500
# _________________________________________________________________
# gru_2 (GRU)                  (None, None, 20)          2520
# _________________________________________________________________
# gru_3 (GRU)                  (None, None, 20)          2520
# _________________________________________________________________
# gru_4 (GRU)                  (None, 20)                2520
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 8,081
# Trainable params: 8,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_val = X_test_scaled.reshape((1, X_test_scaled.shape[0], X_test_scaled.shape[1]))
y_val = y_test_scaled.reshape((1, y_test_scaled.shape[0]))

# %%
# train the model
history_1D = model_1D.fit(X_batch, y_batch[:, 3::2], epochs=20, batch_size=32, validation_data=(X_val, y_val[:, 3::2]), callbacks=callbacks, verbose=1)
# Out:
# Epoch 1/20
#  2/10 [=====>........................] - ETA: 0s - loss: 0.0231
# 2021-11-07 19:31:47.740381: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2021-11-07 19:31:47.740434: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2021-11-07 19:31:47.874153: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2021-11-07 19:31:47.939456: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2021-11-07 19:31:48.057588: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_31_47
#
# 2021-11-07 19:31:48.166177: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ./23_logs/train/plugins/profile/2021_11_07_19_31_47/DiegoM.trace.json.gz
# 2021-11-07 19:31:48.200414: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_31_47
#
# 2021-11-07 19:31:48.200579: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ./23_logs/train/plugins/profile/2021_11_07_19_31_47/DiegoM.memory_profile.json.gz
# 2021-11-07 19:31:48.201927: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./23_logs/train/plugins/profile/2021_11_07_19_31_47
# Dumped tool data for xplane.pb to ./23_logs/train/plugins/profile/2021_11_07_19_31_47/DiegoM.xplane.pb
# Dumped tool data for overview_page.pb to ./23_logs/train/plugins/profile/2021_11_07_19_31_47/DiegoM.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./23_logs/train/plugins/profile/2021_11_07_19_31_47/DiegoM.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./23_logs/train/plugins/profile/2021_11_07_19_31_47/DiegoM.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./23_logs/train/plugins/profile/2021_11_07_19_31_47/DiegoM.kernel_stats.pb
# 10/10 [==============================] - 7s 236ms/step - loss: 0.0148 - val_loss: 0.0095
#
# Epoch 00001: val_loss did not improve from 0.00500
# Epoch 2/20
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0093 - val_loss: 0.0066
#
# Epoch 00002: val_loss did not improve from 0.00500
# Epoch 3/20
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0081 - val_loss: 0.0033
#
# Epoch 00003: val_loss improved from 0.00500 to 0.00334, saving model to 23_checkpoint.keras
# Epoch 4/20
# 10/10 [==============================] - 1s 72ms/step - loss: 0.0075 - val_loss: 0.0033
#
# Epoch 00004: val_loss improved from 0.00334 to 0.00332, saving model to 23_checkpoint.keras
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 5/20
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0073 - val_loss: 0.0033
#
# Epoch 00005: val_loss improved from 0.00332 to 0.00332, saving model to 23_checkpoint.keras
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 6/20
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0073 - val_loss: 0.0034
#
# Epoch 00006: val_loss did not improve from 0.00332
# Epoch 7/20
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0073 - val_loss: 0.0034
#
# Epoch 00007: val_loss did not improve from 0.00332
# Epoch 8/20
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0073 - val_loss: 0.0034
#
# Epoch 00008: val_loss did not improve from 0.00332
# Epoch 9/20
# 10/10 [==============================] - 1s 64ms/step - loss: 0.0073 - val_loss: 0.0034
#
# Epoch 00009: val_loss did not improve from 0.00332
# Epoch 10/20
# 10/10 [==============================] - 1s 67ms/step - loss: 0.0073 - val_loss: 0.0034
#
# Epoch 00010: val_loss did not improve from 0.00332
# Epoch 00010: early stopping

# %%
# plot learning curves
plot_learning_curves(history_1D.history["loss"], history_1D.history["val_loss"])
