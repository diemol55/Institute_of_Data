# %% [markdown]
# **STOCK QUANTITY FORECASTING MODEL APPLIED TO OZWIDE TOOLS SALES TRANSACTIONS**
# ```
# Important note:
# Python Version: 3.8
# Tensorflow Version:  2.6.0
# Keras Version:  2.6.0
# Numpy Version:  1.19.5
# ```

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
import os

# %%
# import data
if 'google.colab' in str(get_ipython()):
  from google.colab import drive
  drive.mount('/content/drive')
  df = pd.read_csv('/content/drive/MyDrive/Institute_of_Data/Capstone/Data/Stock_Movements.csv', parse_dates=['TransactionDate'], index_col='TransactionDate', infer_datetime_format=True, dayfirst=True, encoding='cp1252')
  df_flyers = pd.read_csv('/content/drive/MyDrive/Institute_of_Data/Capstone/Data/Flyers_Signals.csv', parse_dates=['Date'], index_col='Date', infer_datetime_format=True, dayfirst=True)
  print('Running on CoLab')
else:
  print('Not running on CoLab')
  df = pd.read_csv('Data/Stock_Movements.csv', parse_dates=['TransactionDate'], index_col='TransactionDate', infer_datetime_format=True, dayfirst=True, encoding='cp1252')
  df_flyers = pd.read_csv('Data/Flyers_Signals.csv', parse_dates=['Date'], index_col='Date', infer_datetime_format=True, dayfirst=True)
# Out:
# Mounted at /content/drive
# Running on CoLab

# %%
df.head()
# Out:
#                  StockID  ...                          Contact
# TransactionDate           ...
# 2020-07-31          4283  ...  Automotive Test Solutions - ATS
# 2020-09-15          4283  ...                     Wittaya Mala
# 2021-04-12          4581  ...                       TENG TOOLS
# 2021-05-25          4615  ...                       TENG TOOLS
# 2020-07-06             1  ...                       TENG TOOLS
#
# [5 rows x 16 columns]

# %%
# drop rows with part numbers ending with "-R" in Part Column - These are rental parts which are not in the scope of the project
df = df[df.Part.str.contains('-R') == False]
# drop rows with "FREIGHT" and "NETO FREIGHT" in Part Column - Not needed for this project
df = df[df.Part.str.contains('FREIGHT') == False]
df = df[df.Part.str.contains('NETO FREIGHT') == False]

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15592 entries, 2020-07-31 to 2021-06-30
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   StockID           15592 non-null  int64
#  1   Part              15592 non-null  object
#  2   StockDescription  15286 non-null  object
#  3   TransactionID     15592 non-null  int64
#  4   SourceTypeID      15592 non-null  int64
#  5   SourceType        15592 non-null  object
#  6   SourceID          15592 non-null  int64
#  7   Reference         15592 non-null  object
#  8   Detail            11896 non-null  object
#  9   Qty               15592 non-null  float64
#  10  Cost              15590 non-null  float64
#  11  CostEach          15590 non-null  float64
#  12  Amount            15592 non-null  float64
#  13  New Total Qty     14414 non-null  float64
#  14  DocumentID        13934 non-null  float64
#  15  Contact           15003 non-null  object
# dtypes: float64(6), int64(4), object(6)
# memory usage: 2.0+ MB

# %%
# create new dataset subseting df by SourceTypeID 21 and 200  - These two codes are for Qty sold and Qty returned due to credits
df_pur = df.loc[(df['SourceTypeID'] == 21) | (df['SourceTypeID'] == 200)]
df_pur.head()
# Out:
#                  StockID        Part  ... DocumentID         Contact
# TransactionDate                       ...
# 2020-09-15          4283  10I-SERIES  ...     1498.0    Wittaya Mala
# 2021-07-05          3465  ATE-FB30SR  ...     9101.0           Manny
# 2021-02-05          4279     BOR2000  ...     4940.0       Hud Cavka
# 2021-03-11          4279     BOR2000  ...     5264.0  Jason Robinson
# 2021-10-13          4279     BOR2000  ...    12052.0     Leif Coplin
#
# [5 rows x 16 columns]

# %%
# info about the data
df_pur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11912 entries, 2020-09-15 to 2020-07-28
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   StockID           11912 non-null  int64
#  1   Part              11912 non-null  object
#  2   StockDescription  11780 non-null  object
#  3   TransactionID     11912 non-null  int64
#  4   SourceTypeID      11912 non-null  int64
#  5   SourceType        11912 non-null  object
#  6   SourceID          11912 non-null  int64
#  7   Reference         11912 non-null  object
#  8   Detail            8683 non-null   object
#  9   Qty               11912 non-null  float64
#  10  Cost              11912 non-null  float64
#  11  CostEach          11912 non-null  float64
#  12  Amount            11912 non-null  float64
#  13  New Total Qty     11284 non-null  float64
#  14  DocumentID        11892 non-null  float64
#  15  Contact           11892 non-null  object
# dtypes: float64(6), int64(4), object(6)
# memory usage: 1.5+ MB

# %%
# resample the data to daily frequency and sum the columns
df_pur_daily = df_pur.resample('D').sum()
df_pur_daily.head()
# Out:
#                  StockID  TransactionID  ...  New Total Qty  DocumentID
# TransactionDate                          ...
# 2020-07-01           859           2372  ...            4.0         0.0
# 2020-07-02             0              0  ...            0.0         0.0
# 2020-07-03          6398          10147  ...           18.0       158.0
# 2020-07-04             0              0  ...            0.0         0.0
# 2020-07-05             0              0  ...            0.0         0.0
#
# [5 rows x 10 columns]

# %%
# mulyiply the Qty column by -1 to get the net movement
df_pur_daily['Qty'] = df_pur_daily['Qty'] * -1

# %%
# drop last row - las row dropped since it was just the first day of the month
df_pur_daily = df_pur_daily.drop(df_pur_daily.tail(1).index)

# %%
# display the first 5 rows of the dataframe
df_pur_daily.head()
# Out:
#                  StockID  TransactionID  ...  New Total Qty  DocumentID
# TransactionDate                          ...
# 2020-07-01           859           2372  ...            4.0         0.0
# 2020-07-02             0              0  ...            0.0         0.0
# 2020-07-03          6398          10147  ...           18.0       158.0
# 2020-07-04             0              0  ...            0.0         0.0
# 2020-07-05             0              0  ...            0.0         0.0
#
# [5 rows x 10 columns]

# %%
# plot Qty on a daily basis - this is the daily movement of the inventory including weekends and holidays
df_pur_daily['Qty'].plot(figsize=(12, 6))
plt.show()

# %%
# plot Qty on a weekly basis
df_pur_daily['Qty'].resample('W').sum().plot(figsize=(12, 6))
plt.show()

# %%
# plot qty on a monthly basis
df_pur_daily['Qty'].resample('M').sum().plot(figsize=(12, 6))
plt.show()

# %%
# dataset tail
df_pur_daily.tail()
# Out:
#                  StockID  TransactionID  ...  New Total Qty  DocumentID
# TransactionDate                          ...
# 2021-10-27         31635         718885  ...          297.0    261196.0
# 2021-10-28         82061        1270381  ...          488.0    461557.0
# 2021-10-29         68559        1584214  ...          628.0    574717.0
# 2021-10-30             0              0  ...            0.0         0.0
# 2021-10-31             0              0  ...            0.0         0.0
#
# [5 rows x 10 columns]

# %%
# Create a new column with month name and year - this is used to group the data by month and plot the data
df_pur_daily['Month'] = df_pur_daily.index.to_period('M')
df_pur_daily.head()
# Out:
#                  StockID  TransactionID  ...  DocumentID    Month
# TransactionDate                          ...
# 2020-07-01           859           2372  ...         0.0  2020-07
# 2020-07-02             0              0  ...         0.0  2020-07
# 2020-07-03          6398          10147  ...       158.0  2020-07
# 2020-07-04             0              0  ...         0.0  2020-07
# 2020-07-05             0              0  ...         0.0  2020-07
#
# [5 rows x 11 columns]

# %%
# boxplot of Qty by month seaborn - We can notice here that the zero quantities are skewing the data
sns.boxplot(x='Month', y='Qty', data=df_pur_daily, palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
# barplot of Qty by month seaborn
sns.barplot(x='Month', y='Qty', data=df_pur_daily, palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
# create new dataframe with data from Aug 2020 to Oct 31 2021 - we decided to drop the first month data since a new system was implemented and the data wasn't consistent
df_pur_daily_2020 = df_pur_daily.loc['2020-08-01':'2021-10-31']
df_pur_daily_2020.head()
# Out:
#                  StockID  TransactionID  ...  DocumentID    Month
# TransactionDate                          ...
# 2020-08-01             0              0  ...         0.0  2020-08
# 2020-08-02             0              0  ...         0.0  2020-08
# 2020-08-03         47250         169277  ...     31961.0  2020-08
# 2020-08-04         54858         255501  ...     49362.0  2020-08
# 2020-08-05         61756         210211  ...     38749.0  2020-08
#
# [5 rows x 11 columns]

# %%
# plot qty on a daily basis - New data from Aug 2020 to Oct 31 2021
df_pur_daily_2020['Qty'].plot(figsize=(12, 6)) 
plt.show()

# %%
# plot qty on a weekly basis
df_pur_daily_2020['Qty'].resample('W').sum().plot(figsize=(12, 6))
plt.show()

# %%
# plot qty on a monthly basis
df_pur_daily_2020['Qty'].resample('M').sum().plot(figsize=(12, 6))
plt.show()

# %%
# boxplot of Qty by month seaborn - We ploted again the data with zero quantities to compare
sns.boxplot(x='Month', y='Qty', data=df_pur_daily_2020, palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
# plot a histogram of Qty for March 2021
df_pur_daily_2020['Qty'].loc['2021-03-01':'2021-03-31'].plot(kind='hist')
plt.show()

# %%
# We decided to drop the first month since a new system was implemented and the data was not accurate
# We also decided to drop weekends it will creat a lot of noise
df_pur_daily_2020 = df_pur_daily_2020.drop(df_pur_daily_2020[df_pur_daily_2020['Qty'] == 0].index)

# %%
# boxplot of Qty by month zero quantities dropped (Weekends and holidays)
sns.boxplot(x='Month', y='Qty', data=df_pur_daily_2020, palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
# plot a histogram of Qty for March 2021 with weekends dropped - We can notice that the skewness is reduced
df_pur_daily_2020['Qty'].loc['2021-03-01':'2021-03-31'].plot(kind='hist')
plt.show()

# %%
# plot Qty on a daily basis
df_pur_daily_2020['Qty'].plot(figsize=(12, 6))
plt.show()

# %%
# plot Qty on a weekly basis
df_pur_daily_2020['Qty'].resample('W').sum().plot(figsize=(12, 6))
plt.show()

# %%
# import data
# we created a time series with special sales for 2020 and 2021 to input as a signal
df_flyers.head()
# Out:
#             Ozwide Flyer  Hsy Flyer
# Date
# 2020-07-01             0          1
# 2020-07-02             0          1
# 2020-07-03             0          1
# 2020-07-04             0          0
# 2020-07-05             0          0

# %%
# plot df_flyers
df_flyers.plot(figsize=(12, 6))
plt.show()

# %%
# join df_pur_daily_2020 and df_flyers on the index - new dataset including the flyers signal
df_pur_daily_2020_flyers = df_pur_daily_2020.join(df_flyers, how='inner')
df_pur_daily_2020_flyers.head(10)
# Out:
#             StockID  TransactionID  ...  Ozwide Flyer  Hsy Flyer
# 2020-08-03    47250         169277  ...             0          1
# 2020-08-04    54858         255501  ...             0          1
# 2020-08-05    61756         210211  ...             0          1
# 2020-08-06    48940         183010  ...             0          1
# 2020-08-07    16091          60290  ...             0          1
# 2020-08-10    39879         159346  ...             0          0
# 2020-08-11    20926          89053  ...             0          0
# 2020-08-12    65806         159903  ...             0          0
# 2020-08-13    45564         140864  ...             0          0
# 2020-08-14    39918         175975  ...             0          0
#
# [10 rows x 13 columns]

# %%
# we created three new columns with the day, week and month of the year to pick up trends based on seasonal patterns
# create column day of the year
df_pur_daily_2020_flyers['DayOfYear'] = df_pur_daily_2020_flyers.index.dayofyear
# create column day of the week
df_pur_daily_2020_flyers['DayOfWeek'] = df_pur_daily_2020_flyers.index.dayofweek
# create column month
df_pur_daily_2020_flyers['Month'] = df_pur_daily_2020_flyers.index.month
df_pur_daily_2020_flyers.head()
# Out:
#             StockID  TransactionID  ...  DayOfYear  DayOfWeek
# 2020-08-03    47250         169277  ...        216          0
# 2020-08-04    54858         255501  ...        217          1
# 2020-08-05    61756         210211  ...        218          2
# 2020-08-06    48940         183010  ...        219          3
# 2020-08-07    16091          60290  ...        220          4
#
# [5 rows x 15 columns]

# %%
# barplot of Qty by day of the week seaborn
sns.barplot(x='DayOfWeek', y='Qty', data=df_pur_daily_2020_flyers, palette='rainbow')
plt.show()

# %%
# barplot of Qty by day of the week seaborn
sns.barplot(x='Ozwide Flyer', y='Qty', data=df_pur_daily_2020_flyers, palette='rainbow')
plt.show()

# %%
# barplot of Qty by day of the week seaborn
sns.barplot(x='Hsy Flyer', y='Qty', data=df_pur_daily_2020_flyers, palette='rainbow')
plt.show()

# %%
# drop columns StockID, TransactionID, SourceTypeID, SourceID, Cost, CostEach, Amount, New Total Qty, DocumentID
# the result of this dataset is our dataframe with the features needed for the model
df_pur_daily_2020_flyers = df_pur_daily_2020_flyers.drop(['StockID', 'TransactionID', 'SourceTypeID', 'SourceID', 'Cost', 'CostEach', 'Amount', 'New Total Qty', 'DocumentID'], axis=1)
df_pur_daily_2020_flyers.head()
# Out:
#              Qty  Month  Ozwide Flyer  Hsy Flyer  DayOfYear  DayOfWeek
# 2020-08-03  38.0      8             0          1        216          0
# 2020-08-04  44.0      8             0          1        217          1
# 2020-08-05  42.0      8             0          1        218          2
# 2020-08-06  33.0      8             0          1        219          3
# 2020-08-07  10.0      8             0          1        220          4

# %%
# plot Qty, Hsy Flyer and Ozwide Flyer on a daily basis in different plots
fig, axs = plt.subplots(3, 1, figsize=(12, 10))
# add titles to each plot
axs[0].set_title('Qty')
axs[1].set_title('Hsy Flyer')
axs[2].set_title('Ozwide Flyer')
df_pur_daily_2020_flyers['Qty'].plot(ax=axs[0])
df_pur_daily_2020_flyers['Hsy Flyer'].plot(ax=axs[1])
df_pur_daily_2020_flyers['Ozwide Flyer'].plot(ax=axs[2])
fig.tight_layout(pad=2.0)
plt.show()

# %%
# target variable
target = ['Qty']
# time steps in the future
shift_moths = 1
shifth_steps = shift_moths * 30
# create a new column with the shifted values - this is the way to predict the future values based on the past values this is the method used to conver this into a supervised learning problem
df_pur_daily_2020_flyers['Qty_shift'] = df_pur_daily_2020_flyers['Qty'].shift(-shifth_steps)
df_pur_daily_2020_flyers.head()
# Out:
#              Qty  Month  Ozwide Flyer  ...  DayOfYear  DayOfWeek  Qty_shift
# 2020-08-03  38.0      8             0  ...        216          0       30.0
# 2020-08-04  44.0      8             0  ...        217          1       45.0
# 2020-08-05  42.0      8             0  ...        218          2       18.0
# 2020-08-06  33.0      8             0  ...        219          3       41.0
# 2020-08-07  10.0      8             0  ...        220          4       38.0
#
# [5 rows x 7 columns]

# %%
# check the data has been shifted in the future
df_pur_daily_2020_flyers.tail(5)
# Out:
#              Qty  Month  Ozwide Flyer  ...  DayOfYear  DayOfWeek  Qty_shift
# 2021-10-25  42.0     10             0  ...        298          0        NaN
# 2021-10-26  34.0     10             0  ...        299          1        NaN
# 2021-10-27  22.0     10             0  ...        300          2        NaN
# 2021-10-28  40.0     10             0  ...        301          3        NaN
# 2021-10-29  59.0     10             0  ...        302          4        NaN
#
# [5 rows x 7 columns]

# %%
# generate numpy array of the data
X = df_pur_daily_2020_flyers[['Qty','DayOfYear', 'DayOfWeek', 'Month', 'Hsy Flyer', 'Ozwide Flyer']].values[0:-shifth_steps]
y = df_pur_daily_2020_flyers['Qty_shift'].values[0:-shifth_steps]
print('X shape is:', X.shape)
print('y shape is:', y.shape)
# Out:
# X shape is: (290, 6)
# y shape is: (290,)

# %%
# import preprocessing and model selection libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
print('X_train shape is:', X_train.shape)
print('X_test shape is:', X_test.shape)
print('y_train shape is:', y_train.shape)
print('y_test shape is:', y_test.shape)
# Out:
# X_train shape is: (261, 6)
# X_test shape is: (29, 6)
# y_train shape is: (261,)
# y_test shape is: (29,)

# %%
# scale data
X_scaler = MinMaxScaler()
X_train_scaled = X_scaler.fit_transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# data shape
print('X_train_scaled shape is:', X_train_scaled.shape)
print('X_test_scaled shape is:', X_test_scaled.shape)
# Out:
# X_train_scaled shape is: (261, 6)
# X_test_scaled shape is: (29, 6)

# %%
print('Min: ', X_train_scaled.min())
print('Max: ', X_train_scaled.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# scale y data
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.reshape(-1, 1))
y_train_scaled = y_train_scaled.reshape(-1)
y_test_scaled = y_test_scaled.reshape(-1)

# %%
# data shape
print('y_train_scaled shape is:', y_train_scaled.shape)
print('y_test_scaled shape is:', y_test_scaled.shape)
# Out:
# y_train_scaled shape is: (261,)
# y_test_scaled shape is: (29,)

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, 6)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (batch_size, sequence_length)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(X_train.shape[0] - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = X_train_scaled[idx:idx+sequence_length]
            y_batch[i] = y_train_scaled[idx:idx+sequence_length]
        
        yield (x_batch, y_batch)

# %%
X_batch, y_batch = next(batch_generator(batch_size=300, sequence_length=90))

# %%
print(X_batch.shape)
print(y_batch.shape)
# Out:
# (300, 90, 6)
# (300, 90)

# %%
# plot a 3 X 3 plot of X_batch[9 , :, 0]
fig, axs = plt.subplots(3, 3, figsize=(12, 10))
for i in range(9):
    axs[i//3, i%3].plot(X_batch[i, :, 0])
    axs[i//3, i%3].set_title('X_batch[{}]'.format(i))
fig.tight_layout(pad=2.0)
plt.show()

# %%
validation_data = (X_test_scaled.reshape((1, X_test_scaled.shape[0], X_test_scaled.shape[1])), y_test_scaled.reshape((1, y_test_scaled.shape[0])))

# %%
# import RNN libraries tensoflow and keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, SimpleRNN, LSTM, Conv1D, MaxPooling1D, Flatten, TimeDistributed, InputLayer
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras.backend import square, mean
print('Tensorflow Version: ',tf.__version__)
print('Keras Version: ',tf.keras.__version__)
print('Numpy Version: ',np.__version__)
# Out:
# Tensorflow Version:  2.6.0
# Keras Version:  2.6.0
# Numpy Version:  1.19.5

# %%
# learning curves function
def plot_learning_curves(loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    # plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %%
# plot predictions function
def plot_comparison(start_idx, length=100, train=True, model=None):
    """
    Plot the predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if train:
        # Use training-data.
        x = X_train_scaled
        y_true = y_train
    else:
        # Use test-data.
        x = X_test_scaled
        y_true = y_test
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    # x = np.expand_dims(x, axis=0)
    x = x.reshape((1, x.shape[0], x.shape[1]))

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    
    # For each output-signal.
    for signal in range(len(target)):
        # Get the output-signal predicted by the model.
        signal_pred = y_pred_rescaled[:]
        
        # Get the true output-signal from the data-set.
        signal_true = y_true[:]

        # Make the plotting-canvas bigger.
        plt.figure(figsize=(15,5))
        
        # Plot and compare the two signals.
        plt.plot(signal_true, label='true')
        plt.plot(signal_pred, label='pred')
        
        # Plot grey box for warmup-period.
        p = plt.axvspan(0, 5, facecolor='black', alpha=0.15)
        
        # Plot labels etc.
        plt.ylabel(target[signal])
        plt.legend()
        plt.show()
        # print sklearn mean squared error
        print('MSE:', np.sqrt(mean_squared_error(signal_true, signal_pred)))

# %%
# Create the SimpleRNN model
model = Sequential()
model.add(SimpleRNN(50, return_sequences=True, input_shape=(None, 6)))
model.add(SimpleRNN(50, return_sequences=True))
model.add(Dense(1, activation='relu'))

# %%
# %%time
# compile the model
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_batch, y_batch, epochs=200, validation_data=validation_data, verbose=1, steps_per_epoch=50, callbacks=EarlyStopping(monitor='val_loss', patience=100, verbose=1))
# Out:
# Epoch 1/200
# 50/50 [==============================] - 7s 95ms/step - loss: 0.0254 - val_loss: 0.0275
# Epoch 2/200
# 50/50 [==============================] - 4s 90ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 3/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 4/200
# 50/50 [==============================] - 4s 89ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 5/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 6/200
# 50/50 [==============================] - 4s 90ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 7/200
# 50/50 [==============================] - 5s 90ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 8/200
# 50/50 [==============================] - 4s 90ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 9/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 10/200
# 50/50 [==============================] - 5s 90ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 11/200
# 50/50 [==============================] - 4s 89ms/step - loss: 0.0252 - val_loss: 0.0275
# Epoch 12/200
# 50/50 [==============================] - 5s 90ms/step - loss: 0.0252 - val_loss: 0.0272
# Epoch 13/200
# 50/50 [==============================] - 4s 89ms/step - loss: 0.0252 - val_loss: 0.0277
# Epoch 14/200
# 50/50 [==============================] - 4s 90ms/step - loss: 0.0250 - val_loss: 0.0271
# Epoch 15/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0249 - val_loss: 0.0267
# Epoch 16/200
# 50/50 [==============================] - 4s 89ms/step - loss: 0.0248 - val_loss: 0.0247
# Epoch 17/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0247 - val_loss: 0.0246
# Epoch 18/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0245 - val_loss: 0.0275
# Epoch 19/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0252 - val_loss: 0.0273
# Epoch 20/200
# 50/50 [==============================] - 5s 90ms/step - loss: 0.0251 - val_loss: 0.0272
# Epoch 21/200
# 50/50 [==============================] - 4s 90ms/step - loss: 0.0251 - val_loss: 0.0271
# Epoch 22/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0251 - val_loss: 0.0271
# Epoch 23/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0251 - val_loss: 0.0272
# Epoch 24/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0251 - val_loss: 0.0272
# Epoch 25/200
# 50/50 [==============================] - 4s 89ms/step - loss: 0.0251 - val_loss: 0.0272
# Epoch 26/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0251 - val_loss: 0.0271
# Epoch 27/200
# 50/50 [==============================] - 4s 89ms/step - loss: 0.0251 - val_loss: 0.0272
# Epoch 28/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0251 - val_loss: 0.0272
# Epoch 29/200
# 50/50 [==============================] - 4s 88ms/step - loss: 0.0251 - val_loss: 0.0271
# Epoch 30/200
# 50/50 [==============================] - 5s 90ms/step - loss: 0.0251 - val_loss: 0.0272
# Epoch 31/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0251 - val_loss: 0.0268
# Epoch 32/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0250 - val_loss: 0.0267
# Epoch 33/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0250 - val_loss: 0.0270
# Epoch 34/200
# 50/50 [==============================] - 5s 90ms/step - loss: 0.0250 - val_loss: 0.0268
# Epoch 35/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0250 - val_loss: 0.0268
# Epoch 36/200
# 50/50 [==============================] - 5s 90ms/step - loss: 0.0249 - val_loss: 0.0268
# Epoch 37/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0248 - val_loss: 0.0249
# Epoch 38/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0219 - val_loss: 0.0241
# Epoch 39/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0212 - val_loss: 0.0267
# Epoch 40/200
# 50/50 [==============================] - 4s 89ms/step - loss: 0.0155 - val_loss: 0.0105
# Epoch 41/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0042 - val_loss: 0.0083
# Epoch 42/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0019 - val_loss: 0.0093
# Epoch 43/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0016 - val_loss: 0.0100
# Epoch 44/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0015 - val_loss: 0.0093
# Epoch 45/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0013 - val_loss: 0.0098
# Epoch 46/200
# 50/50 [==============================] - 5s 91ms/step - loss: 0.0012 - val_loss: 0.0092
# Epoch 47/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0012 - val_loss: 0.0094
# Epoch 48/200
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0011 - val_loss: 0.0101
# Epoch 49/200
# 50/50 [==============================] - 5s 92ms/step - loss: 9.5073e-04 - val_loss: 0.0097
# Epoch 50/200
# 50/50 [==============================] - 5s 93ms/step - loss: 9.0688e-04 - val_loss: 0.0093
# Epoch 51/200
# 50/50 [==============================] - 5s 94ms/step - loss: 8.9326e-04 - val_loss: 0.0096
# Epoch 52/200
# 50/50 [==============================] - 5s 95ms/step - loss: 8.8179e-04 - val_loss: 0.0097
# Epoch 53/200
# 50/50 [==============================] - 5s 92ms/step - loss: 8.4728e-04 - val_loss: 0.0092
# Epoch 54/200
# 50/50 [==============================] - 4s 89ms/step - loss: 8.5237e-04 - val_loss: 0.0092
# Epoch 55/200
# 50/50 [==============================] - 5s 90ms/step - loss: 8.1586e-04 - val_loss: 0.0095
# Epoch 56/200
# 50/50 [==============================] - 5s 91ms/step - loss: 8.0211e-04 - val_loss: 0.0093
# Epoch 57/200
# 50/50 [==============================] - 5s 91ms/step - loss: 7.9021e-04 - val_loss: 0.0099
# Epoch 58/200
# 50/50 [==============================] - 5s 91ms/step - loss: 7.5180e-04 - val_loss: 0.0100
# Epoch 59/200
# 50/50 [==============================] - 5s 91ms/step - loss: 7.2177e-04 - val_loss: 0.0099
# Epoch 60/200
# 50/50 [==============================] - 5s 91ms/step - loss: 7.1311e-04 - val_loss: 0.0103
# Epoch 61/200
# 50/50 [==============================] - 5s 92ms/step - loss: 7.3726e-04 - val_loss: 0.0110
# Epoch 62/200
# 50/50 [==============================] - 4s 89ms/step - loss: 7.3468e-04 - val_loss: 0.0108
# Epoch 63/200
# 50/50 [==============================] - 5s 92ms/step - loss: 6.8723e-04 - val_loss: 0.0108
# Epoch 64/200
# 50/50 [==============================] - 4s 90ms/step - loss: 6.8294e-04 - val_loss: 0.0109
# Epoch 65/200
# 50/50 [==============================] - 5s 91ms/step - loss: 6.7006e-04 - val_loss: 0.0110
# Epoch 66/200
# 50/50 [==============================] - 5s 90ms/step - loss: 6.7278e-04 - val_loss: 0.0117
# Epoch 67/200
# 50/50 [==============================] - 5s 92ms/step - loss: 6.4788e-04 - val_loss: 0.0113
# Epoch 68/200
# 50/50 [==============================] - 5s 91ms/step - loss: 6.5796e-04 - val_loss: 0.0113
# Epoch 69/200
# 50/50 [==============================] - 5s 90ms/step - loss: 6.6443e-04 - val_loss: 0.0116
# Epoch 70/200
# 50/50 [==============================] - 5s 92ms/step - loss: 6.1690e-04 - val_loss: 0.0120
# Epoch 71/200
# 50/50 [==============================] - 5s 91ms/step - loss: 5.6621e-04 - val_loss: 0.0122
# Epoch 72/200
# 50/50 [==============================] - 4s 90ms/step - loss: 5.4898e-04 - val_loss: 0.0123
# Epoch 73/200
# 50/50 [==============================] - 5s 91ms/step - loss: 5.5043e-04 - val_loss: 0.0121
# Epoch 74/200
# 50/50 [==============================] - 5s 94ms/step - loss: 5.5026e-04 - val_loss: 0.0122
# Epoch 75/200
# 50/50 [==============================] - 5s 92ms/step - loss: 5.3580e-04 - val_loss: 0.0124
# Epoch 76/200
# 50/50 [==============================] - 5s 91ms/step - loss: 5.4165e-04 - val_loss: 0.0127
# Epoch 77/200
# 50/50 [==============================] - 5s 93ms/step - loss: 5.3278e-04 - val_loss: 0.0124
# Epoch 78/200
# 50/50 [==============================] - 5s 92ms/step - loss: 5.2917e-04 - val_loss: 0.0127
# Epoch 79/200
# 50/50 [==============================] - 5s 95ms/step - loss: 5.1398e-04 - val_loss: 0.0131
# Epoch 80/200
# 50/50 [==============================] - 5s 92ms/step - loss: 5.1752e-04 - val_loss: 0.0128
# Epoch 81/200
# 50/50 [==============================] - 5s 90ms/step - loss: 5.1400e-04 - val_loss: 0.0132
# Epoch 82/200
# 50/50 [==============================] - 5s 92ms/step - loss: 4.9749e-04 - val_loss: 0.0136
# Epoch 83/200
# 50/50 [==============================] - 5s 92ms/step - loss: 4.4218e-04 - val_loss: 0.0138
# Epoch 84/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.5039e-04 - val_loss: 0.0139
# Epoch 85/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.3247e-04 - val_loss: 0.0140
# Epoch 86/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.6522e-04 - val_loss: 0.0143
# Epoch 87/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.3833e-04 - val_loss: 0.0142
# Epoch 88/200
# 50/50 [==============================] - 5s 93ms/step - loss: 4.4338e-04 - val_loss: 0.0143
# Epoch 89/200
# 50/50 [==============================] - 5s 92ms/step - loss: 4.1917e-04 - val_loss: 0.0144
# Epoch 90/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.1398e-04 - val_loss: 0.0148
# Epoch 91/200
# 50/50 [==============================] - 5s 90ms/step - loss: 4.1037e-04 - val_loss: 0.0146
# Epoch 92/200
# 50/50 [==============================] - 5s 90ms/step - loss: 4.0717e-04 - val_loss: 0.0143
# Epoch 93/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.0348e-04 - val_loss: 0.0148
# Epoch 94/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.1540e-04 - val_loss: 0.0152
# Epoch 95/200
# 50/50 [==============================] - 4s 89ms/step - loss: 4.1088e-04 - val_loss: 0.0151
# Epoch 96/200
# 50/50 [==============================] - 5s 91ms/step - loss: 3.9550e-04 - val_loss: 0.0153
# Epoch 97/200
# 50/50 [==============================] - 4s 90ms/step - loss: 4.0223e-04 - val_loss: 0.0156
# Epoch 98/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.0953e-04 - val_loss: 0.0155
# Epoch 99/200
# 50/50 [==============================] - 5s 91ms/step - loss: 4.0354e-04 - val_loss: 0.0156
# Epoch 100/200
# 50/50 [==============================] - 4s 90ms/step - loss: 3.9219e-04 - val_loss: 0.0158
# Epoch 101/200
# 50/50 [==============================] - 4s 90ms/step - loss: 4.0014e-04 - val_loss: 0.0157
# Epoch 102/200
# 50/50 [==============================] - 5s 91ms/step - loss: 3.9784e-04 - val_loss: 0.0159
# Epoch 103/200
# 50/50 [==============================] - 5s 91ms/step - loss: 3.9060e-04 - val_loss: 0.0160
# Epoch 104/200
# 50/50 [==============================] - 5s 91ms/step - loss: 3.9494e-04 - val_loss: 0.0160
# Epoch 105/200
# 50/50 [==============================] - 4s 89ms/step - loss: 3.7660e-04 - val_loss: 0.0158
# Epoch 106/200
# 50/50 [==============================] - 4s 88ms/step - loss: 3.8717e-04 - val_loss: 0.0159
# Epoch 107/200
# 50/50 [==============================] - 5s 91ms/step - loss: 3.8248e-04 - val_loss: 0.0165
# Epoch 108/200
# 50/50 [==============================] - 4s 88ms/step - loss: 3.9045e-04 - val_loss: 0.0162
# Epoch 109/200
# 50/50 [==============================] - 5s 91ms/step - loss: 3.8468e-04 - val_loss: 0.0163
# Epoch 110/200
# 50/50 [==============================] - 4s 90ms/step - loss: 3.1984e-04 - val_loss: 0.0169
# Epoch 111/200
# 50/50 [==============================] - 5s 91ms/step - loss: 3.1269e-04 - val_loss: 0.0164
# Epoch 112/200
# 50/50 [==============================] - 4s 90ms/step - loss: 3.1740e-04 - val_loss: 0.0161
# Epoch 113/200
# 50/50 [==============================] - 4s 88ms/step - loss: 2.9596e-04 - val_loss: 0.0159
# Epoch 114/200
# 50/50 [==============================] - 5s 90ms/step - loss: 2.9160e-04 - val_loss: 0.0162
# Epoch 115/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.9017e-04 - val_loss: 0.0158
# Epoch 116/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.8756e-04 - val_loss: 0.0158
# Epoch 117/200
# 50/50 [==============================] - 4s 90ms/step - loss: 2.8802e-04 - val_loss: 0.0163
# Epoch 118/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.9219e-04 - val_loss: 0.0165
# Epoch 119/200
# 50/50 [==============================] - 5s 92ms/step - loss: 2.9069e-04 - val_loss: 0.0158
# Epoch 120/200
# 50/50 [==============================] - 5s 94ms/step - loss: 2.9059e-04 - val_loss: 0.0160
# Epoch 121/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.8298e-04 - val_loss: 0.0159
# Epoch 122/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.9852e-04 - val_loss: 0.0162
# Epoch 123/200
# 50/50 [==============================] - 5s 90ms/step - loss: 2.8834e-04 - val_loss: 0.0159
# Epoch 124/200
# 50/50 [==============================] - 5s 92ms/step - loss: 2.8427e-04 - val_loss: 0.0156
# Epoch 125/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.9995e-04 - val_loss: 0.0159
# Epoch 126/200
# 50/50 [==============================] - 5s 90ms/step - loss: 2.8126e-04 - val_loss: 0.0161
# Epoch 127/200
# 50/50 [==============================] - 5s 90ms/step - loss: 2.8259e-04 - val_loss: 0.0160
# Epoch 128/200
# 50/50 [==============================] - 4s 89ms/step - loss: 2.7657e-04 - val_loss: 0.0157
# Epoch 129/200
# 50/50 [==============================] - 5s 92ms/step - loss: 2.7464e-04 - val_loss: 0.0155
# Epoch 130/200
# 50/50 [==============================] - 5s 90ms/step - loss: 2.7116e-04 - val_loss: 0.0158
# Epoch 131/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.7021e-04 - val_loss: 0.0155
# Epoch 132/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.6812e-04 - val_loss: 0.0156
# Epoch 133/200
# 50/50 [==============================] - 4s 89ms/step - loss: 2.6549e-04 - val_loss: 0.0157
# Epoch 134/200
# 50/50 [==============================] - 4s 90ms/step - loss: 2.8704e-04 - val_loss: 0.0155
# Epoch 135/200
# 50/50 [==============================] - 4s 90ms/step - loss: 2.6581e-04 - val_loss: 0.0153
# Epoch 136/200
# 50/50 [==============================] - 4s 88ms/step - loss: 2.8274e-04 - val_loss: 0.0154
# Epoch 137/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.8086e-04 - val_loss: 0.0149
# Epoch 138/200
# 50/50 [==============================] - 5s 91ms/step - loss: 2.6223e-04 - val_loss: 0.0151
# Epoch 139/200
# 50/50 [==============================] - 4s 90ms/step - loss: 2.6312e-04 - val_loss: 0.0154
# Epoch 140/200
# 50/50 [==============================] - 5s 92ms/step - loss: 2.6092e-04 - val_loss: 0.0155
# Epoch 141/200
# 50/50 [==============================] - 4s 89ms/step - loss: 2.7134e-04 - val_loss: 0.0149
# Epoch 00141: early stopping
# CPU times: user 14min 58s, sys: 1min 33s, total: 16min 32s
# Wall time: 10min 43s

# %%
# plot learning curves
plot_learning_curves(history.history['loss'])
plt.show()

# %%
# plot predictions train
plot_comparison(start_idx=50, length=250, train=True, model=model)
# Out:
# MSE: 2.7125771947364585

# %%
# plot predictions test
plot_comparison(start_idx=0, length=20, train=False, model=model)
# Out:
# MSE: 22.775383570437466

# %%
# create LSTM model
model_LSTM = Sequential()
model_LSTM.add(LSTM(50, return_sequences=True, input_shape=(None, 6)))
model_LSTM.add(LSTM(50, return_sequences=True))
model_LSTM.add(Dense(1, activation='relu'))

# %%
# %%time
# compile the model
model_LSTM.compile(optimizer='adam', loss='mse')
history_LSTM = model_LSTM.fit(X_batch, y_batch, epochs=200, validation_data=validation_data, verbose=1, steps_per_epoch=100, callbacks=EarlyStopping(monitor='val_loss', patience=50, verbose=1))
# Out:
# Epoch 1/200
# 100/100 [==============================] - 5s 14ms/step - loss: 0.0083 - val_loss: 0.0060
# Epoch 2/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0073 - val_loss: 0.0056
# Epoch 3/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0067 - val_loss: 0.0070
# Epoch 4/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0063 - val_loss: 0.0077
# Epoch 5/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0060 - val_loss: 0.0096
# Epoch 6/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0055 - val_loss: 0.0100
# Epoch 7/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0049 - val_loss: 0.0140
# Epoch 8/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0041 - val_loss: 0.0204
# Epoch 9/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 0.0227
# Epoch 10/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0030 - val_loss: 0.0210
# Epoch 11/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0026 - val_loss: 0.0272
# Epoch 12/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0024 - val_loss: 0.0219
# Epoch 13/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0022 - val_loss: 0.0226
# Epoch 14/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0020 - val_loss: 0.0221
# Epoch 15/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0019 - val_loss: 0.0260
# Epoch 16/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0019 - val_loss: 0.0218
# Epoch 17/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0018 - val_loss: 0.0224
# Epoch 18/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0018 - val_loss: 0.0232
# Epoch 19/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0016 - val_loss: 0.0246
# Epoch 20/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0016 - val_loss: 0.0214
# Epoch 21/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0015 - val_loss: 0.0191
# Epoch 22/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0014 - val_loss: 0.0207
# Epoch 23/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0014 - val_loss: 0.0193
# Epoch 24/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0013 - val_loss: 0.0167
# Epoch 25/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0012 - val_loss: 0.0166
# Epoch 26/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0012 - val_loss: 0.0164
# Epoch 27/200
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0011 - val_loss: 0.0178
# Epoch 28/200
# 100/100 [==============================] - 1s 7ms/step - loss: 9.9349e-04 - val_loss: 0.0162
# Epoch 29/200
# 100/100 [==============================] - 1s 7ms/step - loss: 9.6268e-04 - val_loss: 0.0177
# Epoch 30/200
# 100/100 [==============================] - 1s 7ms/step - loss: 8.7251e-04 - val_loss: 0.0159
# Epoch 31/200
# 100/100 [==============================] - 1s 7ms/step - loss: 8.3205e-04 - val_loss: 0.0173
# Epoch 32/200
# 100/100 [==============================] - 1s 7ms/step - loss: 7.9519e-04 - val_loss: 0.0175
# Epoch 33/200
# 100/100 [==============================] - 1s 7ms/step - loss: 7.5038e-04 - val_loss: 0.0174
# Epoch 34/200
# 100/100 [==============================] - 1s 7ms/step - loss: 6.8574e-04 - val_loss: 0.0171
# Epoch 35/200
# 100/100 [==============================] - 1s 7ms/step - loss: 6.5657e-04 - val_loss: 0.0165
# Epoch 36/200
# 100/100 [==============================] - 1s 7ms/step - loss: 6.4546e-04 - val_loss: 0.0166
# Epoch 37/200
# 100/100 [==============================] - 1s 7ms/step - loss: 6.3022e-04 - val_loss: 0.0165
# Epoch 38/200
# 100/100 [==============================] - 1s 7ms/step - loss: 6.0203e-04 - val_loss: 0.0167
# Epoch 39/200
# 100/100 [==============================] - 1s 7ms/step - loss: 5.8535e-04 - val_loss: 0.0178
# Epoch 40/200
# 100/100 [==============================] - 1s 7ms/step - loss: 5.7379e-04 - val_loss: 0.0163
# Epoch 41/200
# 100/100 [==============================] - 1s 7ms/step - loss: 5.3604e-04 - val_loss: 0.0167
# Epoch 42/200
# 100/100 [==============================] - 1s 7ms/step - loss: 5.2016e-04 - val_loss: 0.0170
# Epoch 43/200
# 100/100 [==============================] - 1s 7ms/step - loss: 5.1387e-04 - val_loss: 0.0170
# Epoch 44/200
# 100/100 [==============================] - 1s 7ms/step - loss: 5.0808e-04 - val_loss: 0.0179
# Epoch 45/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.8195e-04 - val_loss: 0.0180
# Epoch 46/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.6902e-04 - val_loss: 0.0179
# Epoch 47/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.4652e-04 - val_loss: 0.0194
# Epoch 48/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.5419e-04 - val_loss: 0.0191
# Epoch 49/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.3228e-04 - val_loss: 0.0190
# Epoch 50/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.2975e-04 - val_loss: 0.0196
# Epoch 51/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.1924e-04 - val_loss: 0.0209
# Epoch 52/200
# 100/100 [==============================] - 1s 7ms/step - loss: 4.0408e-04 - val_loss: 0.0218
# Epoch 00052: early stopping
# CPU times: user 43.2 s, sys: 2.27 s, total: 45.5 s
# Wall time: 41.7 s

# %%
model_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 50)          11400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 50)          20200
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 1)           51
# =================================================================
# Total params: 31,651
# Trainable params: 31,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot learning curves
plot_learning_curves(history_LSTM.history['loss'])
plt.show()

# %%
# plot predictions train
plot_comparison(start_idx=50, length=250, train=True, model=model_LSTM)
# Out:
# MSE: 3.042882207915885

# %%
# plot predictions test
plot_comparison(start_idx=0, length=20, train=False, model=model_LSTM)
# Out:
# MSE: 38.66871177578946

# %%
# Create GRU model
model_GRU = Sequential()
model_GRU.add(GRU(units=50, return_sequences=True, input_shape=(None, 6)))
model_GRU.add(GRU(units=50, return_sequences=True))
model_GRU.add(Dense(units=1, activation='relu'))

# %%
# %%time
# compile the model
model_GRU.compile(optimizer='adam', loss='mse')
history_GRU = model_GRU.fit(X_batch, y_batch, epochs=200, validation_data=validation_data, verbose=1, steps_per_epoch=200, callbacks=EarlyStopping(monitor='val_loss', patience=50, verbose=1))
# Out:
# Epoch 1/200
# 200/200 [==============================] - 4s 10ms/step - loss: 0.0077 - val_loss: 0.0049
# Epoch 2/200
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 3/200
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0046 - val_loss: 0.0135
# Epoch 4/200
# 200/200 [==============================] - 1s 6ms/step - loss: 0.0018 - val_loss: 0.0127
# Epoch 5/200
# 200/200 [==============================] - 1s 7ms/step - loss: 8.3593e-04 - val_loss: 0.0114
# Epoch 6/200
# 200/200 [==============================] - 1s 6ms/step - loss: 6.1305e-04 - val_loss: 0.0117
# Epoch 7/200
# 200/200 [==============================] - 1s 7ms/step - loss: 4.7587e-04 - val_loss: 0.0119
# Epoch 8/200
# 200/200 [==============================] - 1s 6ms/step - loss: 4.2024e-04 - val_loss: 0.0123
# Epoch 9/200
# 200/200 [==============================] - 1s 6ms/step - loss: 3.7517e-04 - val_loss: 0.0131
# Epoch 10/200
# 200/200 [==============================] - 1s 7ms/step - loss: 3.5905e-04 - val_loss: 0.0137
# Epoch 11/200
# 200/200 [==============================] - 1s 6ms/step - loss: 3.3239e-04 - val_loss: 0.0147
# Epoch 12/200
# 200/200 [==============================] - 1s 6ms/step - loss: 3.2494e-04 - val_loss: 0.0147
# Epoch 13/200
# 200/200 [==============================] - 1s 6ms/step - loss: 3.1376e-04 - val_loss: 0.0152
# Epoch 14/200
# 200/200 [==============================] - 1s 7ms/step - loss: 3.0777e-04 - val_loss: 0.0168
# Epoch 15/200
# 200/200 [==============================] - 1s 6ms/step - loss: 2.8474e-04 - val_loss: 0.0173
# Epoch 16/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.8216e-04 - val_loss: 0.0190
# Epoch 17/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.9456e-04 - val_loss: 0.0185
# Epoch 18/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.5635e-04 - val_loss: 0.0210
# Epoch 19/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.6788e-04 - val_loss: 0.0211
# Epoch 20/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.1938e-04 - val_loss: 0.0225
# Epoch 21/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.9136e-04 - val_loss: 0.0249
# Epoch 22/200
# 200/200 [==============================] - 1s 6ms/step - loss: 2.5675e-04 - val_loss: 0.0254
# Epoch 23/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.3161e-04 - val_loss: 0.0265
# Epoch 24/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.4435e-04 - val_loss: 0.0283
# Epoch 25/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.3289e-04 - val_loss: 0.0291
# Epoch 26/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.2390e-04 - val_loss: 0.0327
# Epoch 27/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.4007e-04 - val_loss: 0.0314
# Epoch 28/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.5812e-04 - val_loss: 0.0341
# Epoch 29/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.9707e-04 - val_loss: 0.0331
# Epoch 30/200
# 200/200 [==============================] - 1s 6ms/step - loss: 2.2319e-04 - val_loss: 0.0354
# Epoch 31/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.3193e-04 - val_loss: 0.0351
# Epoch 32/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.9701e-04 - val_loss: 0.0363
# Epoch 33/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.1314e-04 - val_loss: 0.0395
# Epoch 34/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.9194e-04 - val_loss: 0.0381
# Epoch 35/200
# 200/200 [==============================] - 1s 6ms/step - loss: 2.3166e-04 - val_loss: 0.0374
# Epoch 36/200
# 200/200 [==============================] - 1s 6ms/step - loss: 2.0590e-04 - val_loss: 0.0419
# Epoch 37/200
# 200/200 [==============================] - 1s 6ms/step - loss: 2.0615e-04 - val_loss: 0.0389
# Epoch 38/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.0708e-04 - val_loss: 0.0403
# Epoch 39/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.9291e-04 - val_loss: 0.0413
# Epoch 40/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.9079e-04 - val_loss: 0.0447
# Epoch 41/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.2782e-04 - val_loss: 0.0411
# Epoch 42/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.7263e-04 - val_loss: 0.0404
# Epoch 43/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.6971e-04 - val_loss: 0.0424
# Epoch 44/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.3244e-04 - val_loss: 0.0406
# Epoch 45/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.7241e-04 - val_loss: 0.0430
# Epoch 46/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.9033e-04 - val_loss: 0.0411
# Epoch 47/200
# 200/200 [==============================] - 1s 7ms/step - loss: 2.0570e-04 - val_loss: 0.0420
# Epoch 48/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.6075e-04 - val_loss: 0.0421
# Epoch 49/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.9017e-04 - val_loss: 0.0412
# Epoch 50/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.9246e-04 - val_loss: 0.0410
# Epoch 51/200
# 200/200 [==============================] - 1s 7ms/step - loss: 1.6204e-04 - val_loss: 0.0398
# Epoch 00051: early stopping
# CPU times: user 1min 13s, sys: 3.55 s, total: 1min 17s
# Wall time: 1min 9s

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, None, 50)          2850
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, None, 50)          5050
# _________________________________________________________________
# dense (Dense)                (None, None, 1)           51
# =================================================================
# Total params: 7,951
# Trainable params: 7,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot learning curves
plot_learning_curves(history_GRU.history["loss"])
plt.show()

# %%
# plot predictions train
plot_comparison(start_idx=50, length=250, train=True, model=model_GRU)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff01fb980e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MSE: 1.7948076392503678

# %%
# plot predictions test
plot_comparison(start_idx=0, length=20, train=False, model=model_GRU)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff01fb980e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MSE: 57.978555330653286

# %%
# Data preprocessing for 1D CNN
# Scale X
X_scaler_1D = MinMaxScaler()
X_scaled_1D = X_scaler_1D.fit_transform(X)

# %%
def batch_generator_1D(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, 6)
        batch_1D = np.zeros(shape=x_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(X.shape[0] - sequence_length)
            
            # Copy the sequences of data starting at this index.
            batch_1D[i] = X_scaled_1D[idx:idx+sequence_length]
        
        yield (batch_1D)

# %%
batch_1D = next(batch_generator_1D(batch_size=300, sequence_length=120))

# %%
# Batch for 1D convolutional
X_train_1D = batch_1D[:210, :90]
X_valid_1D = batch_1D[210:270, :90]
X_test_1D = batch_1D[270:, :90]
Y_1D = np.empty((300,90,30))
for step_ahead in range (1, 30+1):
  Y_1D[..., step_ahead - 1] = batch_1D[..., step_ahead:step_ahead + 90, 0]
y_train_1D = Y_1D[:210]
y_valid_1D = Y_1D[210:270]
y_test_1D = Y_1D[270:]

# %%
X_train_1D.shape, y_train_1D.shape
# Out:
# ((210, 90, 6), (210, 90, 30))

# %%
# create convolutional model
model_1D = Sequential()
model_1D.add(InputLayer(input_shape=[None, 6]))
for rate in (1, 2, 4, 8) * 2:
    model_1D.add(Conv1D(filters=60, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model_1D.add(Conv1D(filters=30, kernel_size=1))

# %%
# compile the model
model_1D.compile(loss="mse", optimizer="adam")

# %%
model_1D.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, None, 60)          780
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 60)          7260
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, None, 60)          7260
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, None, 60)          7260
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, None, 60)          7260
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, None, 60)          7260
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, None, 60)          7260
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, None, 60)          7260
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, None, 30)          1830
# =================================================================
# Total params: 53,430
# Trainable params: 53,430
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
# train the model
history_1D = model_1D.fit(X_train_1D, y_train_1D, epochs=500, validation_data=(X_valid_1D, y_valid_1D),callbacks=EarlyStopping(monitor='val_loss', patience=50, verbose=1))
# Out:
# Epoch 1/500
# 7/7 [==============================] - 14s 69ms/step - loss: 0.0231 - val_loss: 0.0183
# Epoch 2/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0156 - val_loss: 0.0134
# Epoch 3/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0121 - val_loss: 0.0112
# Epoch 4/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0104 - val_loss: 0.0100
# Epoch 5/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0094
# Epoch 6/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 7/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 8/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 9/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 10/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 11/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 12/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 13/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 14/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 15/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0075
# Epoch 16/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 17/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0069 - val_loss: 0.0069
# Epoch 18/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0065 - val_loss: 0.0065
# Epoch 19/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0062 - val_loss: 0.0062
# Epoch 20/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 21/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0055
# Epoch 22/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 23/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 24/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 25/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 26/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 27/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 28/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 29/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 30/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0030
# Epoch 31/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 32/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 33/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 34/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 35/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 36/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 37/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 38/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 39/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 40/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 41/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 42/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 43/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 44/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 45/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 46/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 47/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 48/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 49/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 50/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 51/500
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 52/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 53/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 54/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 55/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 56/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 57/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 58/500
# 7/7 [==============================] - 0s 8ms/step - loss: 9.9569e-04 - val_loss: 0.0011
# Epoch 59/500
# 7/7 [==============================] - 0s 9ms/step - loss: 9.7892e-04 - val_loss: 0.0010
# Epoch 60/500
# 7/7 [==============================] - 0s 8ms/step - loss: 9.5564e-04 - val_loss: 0.0010
# Epoch 61/500
# 7/7 [==============================] - 0s 9ms/step - loss: 9.2907e-04 - val_loss: 9.8131e-04
# Epoch 62/500
# 7/7 [==============================] - 0s 9ms/step - loss: 9.0529e-04 - val_loss: 9.6251e-04
# Epoch 63/500
# 7/7 [==============================] - 0s 9ms/step - loss: 8.9006e-04 - val_loss: 9.4772e-04
# Epoch 64/500
# 7/7 [==============================] - 0s 9ms/step - loss: 8.7023e-04 - val_loss: 9.3473e-04
# Epoch 65/500
# 7/7 [==============================] - 0s 11ms/step - loss: 8.6013e-04 - val_loss: 9.1346e-04
# Epoch 66/500
# 7/7 [==============================] - 0s 9ms/step - loss: 8.4133e-04 - val_loss: 9.0229e-04
# Epoch 67/500
# 7/7 [==============================] - 0s 9ms/step - loss: 8.2986e-04 - val_loss: 8.8436e-04
# Epoch 68/500
# 7/7 [==============================] - 0s 9ms/step - loss: 8.1417e-04 - val_loss: 8.7652e-04
# Epoch 69/500
# 7/7 [==============================] - 0s 10ms/step - loss: 8.0141e-04 - val_loss: 8.5405e-04
# Epoch 70/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.8710e-04 - val_loss: 8.5763e-04
# Epoch 71/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.8494e-04 - val_loss: 8.4044e-04
# Epoch 72/500
# 7/7 [==============================] - 0s 8ms/step - loss: 7.7273e-04 - val_loss: 8.3363e-04
# Epoch 73/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.5674e-04 - val_loss: 8.0893e-04
# Epoch 74/500
# 7/7 [==============================] - 0s 10ms/step - loss: 7.3834e-04 - val_loss: 7.9915e-04
# Epoch 75/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.2358e-04 - val_loss: 7.8731e-04
# Epoch 76/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.1431e-04 - val_loss: 7.7489e-04
# Epoch 77/500
# 7/7 [==============================] - 0s 9ms/step - loss: 7.0367e-04 - val_loss: 7.6808e-04
# Epoch 78/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.9716e-04 - val_loss: 7.5734e-04
# Epoch 79/500
# 7/7 [==============================] - 0s 10ms/step - loss: 6.9218e-04 - val_loss: 7.6291e-04
# Epoch 80/500
# 7/7 [==============================] - 0s 10ms/step - loss: 6.8468e-04 - val_loss: 7.4471e-04
# Epoch 81/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.7008e-04 - val_loss: 7.3385e-04
# Epoch 82/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.5949e-04 - val_loss: 7.2440e-04
# Epoch 83/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.5210e-04 - val_loss: 7.1780e-04
# Epoch 84/500
# 7/7 [==============================] - 0s 8ms/step - loss: 6.4394e-04 - val_loss: 7.1065e-04
# Epoch 85/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.3688e-04 - val_loss: 7.0465e-04
# Epoch 86/500
# 7/7 [==============================] - 0s 10ms/step - loss: 6.3254e-04 - val_loss: 7.0591e-04
# Epoch 87/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.2954e-04 - val_loss: 6.9423e-04
# Epoch 88/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.2821e-04 - val_loss: 6.8858e-04
# Epoch 89/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.1833e-04 - val_loss: 6.9457e-04
# Epoch 90/500
# 7/7 [==============================] - 0s 9ms/step - loss: 6.1446e-04 - val_loss: 6.7758e-04
# Epoch 91/500
# 7/7 [==============================] - 0s 10ms/step - loss: 6.0121e-04 - val_loss: 6.6888e-04
# Epoch 92/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.9661e-04 - val_loss: 6.6728e-04
# Epoch 93/500
# 7/7 [==============================] - 0s 8ms/step - loss: 5.9021e-04 - val_loss: 6.5553e-04
# Epoch 94/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.8486e-04 - val_loss: 6.5374e-04
# Epoch 95/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.7954e-04 - val_loss: 6.4670e-04
# Epoch 96/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.7433e-04 - val_loss: 6.4008e-04
# Epoch 97/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.7228e-04 - val_loss: 6.3630e-04
# Epoch 98/500
# 7/7 [==============================] - 0s 11ms/step - loss: 5.6129e-04 - val_loss: 6.3383e-04
# Epoch 99/500
# 7/7 [==============================] - 0s 8ms/step - loss: 5.5731e-04 - val_loss: 6.3269e-04
# Epoch 100/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.5299e-04 - val_loss: 6.2289e-04
# Epoch 101/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.4773e-04 - val_loss: 6.1444e-04
# Epoch 102/500
# 7/7 [==============================] - 0s 8ms/step - loss: 5.4108e-04 - val_loss: 6.1174e-04
# Epoch 103/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.3748e-04 - val_loss: 6.1397e-04
# Epoch 104/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.3761e-04 - val_loss: 6.0380e-04
# Epoch 105/500
# 7/7 [==============================] - 0s 8ms/step - loss: 5.3167e-04 - val_loss: 6.1444e-04
# Epoch 106/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.4159e-04 - val_loss: 6.1537e-04
# Epoch 107/500
# 7/7 [==============================] - 0s 11ms/step - loss: 5.3027e-04 - val_loss: 6.1361e-04
# Epoch 108/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.3133e-04 - val_loss: 5.9454e-04
# Epoch 109/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2035e-04 - val_loss: 5.8195e-04
# Epoch 110/500
# 7/7 [==============================] - 0s 10ms/step - loss: 5.1005e-04 - val_loss: 5.8184e-04
# Epoch 111/500
# 7/7 [==============================] - 0s 8ms/step - loss: 5.0656e-04 - val_loss: 5.7496e-04
# Epoch 112/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.0443e-04 - val_loss: 5.7787e-04
# Epoch 113/500
# 7/7 [==============================] - 0s 9ms/step - loss: 5.0021e-04 - val_loss: 5.6860e-04
# Epoch 114/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.9508e-04 - val_loss: 5.6792e-04
# Epoch 115/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.9698e-04 - val_loss: 5.7682e-04
# Epoch 116/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9800e-04 - val_loss: 5.6056e-04
# Epoch 117/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.8832e-04 - val_loss: 5.6033e-04
# Epoch 118/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.8452e-04 - val_loss: 5.6634e-04
# Epoch 119/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.9005e-04 - val_loss: 5.5520e-04
# Epoch 120/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.8178e-04 - val_loss: 5.4782e-04
# Epoch 121/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7434e-04 - val_loss: 5.4712e-04
# Epoch 122/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.7380e-04 - val_loss: 5.3859e-04
# Epoch 123/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.6845e-04 - val_loss: 5.3494e-04
# Epoch 124/500
# 7/7 [==============================] - 0s 12ms/step - loss: 4.6360e-04 - val_loss: 5.3351e-04
# Epoch 125/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.6158e-04 - val_loss: 5.3539e-04
# Epoch 126/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.5823e-04 - val_loss: 5.2951e-04
# Epoch 127/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.5926e-04 - val_loss: 5.2630e-04
# Epoch 128/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6114e-04 - val_loss: 5.1951e-04
# Epoch 129/500
# 7/7 [==============================] - 0s 11ms/step - loss: 4.5310e-04 - val_loss: 5.2034e-04
# Epoch 130/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.4715e-04 - val_loss: 5.2145e-04
# Epoch 131/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.5242e-04 - val_loss: 5.1336e-04
# Epoch 132/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.4503e-04 - val_loss: 5.2563e-04
# Epoch 133/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.5911e-04 - val_loss: 5.2835e-04
# Epoch 134/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.4780e-04 - val_loss: 5.1829e-04
# Epoch 135/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.4713e-04 - val_loss: 5.0943e-04
# Epoch 136/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.3823e-04 - val_loss: 5.0495e-04
# Epoch 137/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.3368e-04 - val_loss: 5.0069e-04
# Epoch 138/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2806e-04 - val_loss: 4.9753e-04
# Epoch 139/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2478e-04 - val_loss: 4.9399e-04
# Epoch 140/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2219e-04 - val_loss: 4.9188e-04
# Epoch 141/500
# 7/7 [==============================] - 0s 12ms/step - loss: 4.2006e-04 - val_loss: 4.9295e-04
# Epoch 142/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.2071e-04 - val_loss: 4.9092e-04
# Epoch 143/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2882e-04 - val_loss: 4.9537e-04
# Epoch 144/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.2177e-04 - val_loss: 4.9405e-04
# Epoch 145/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2252e-04 - val_loss: 4.8720e-04
# Epoch 146/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2241e-04 - val_loss: 4.8623e-04
# Epoch 147/500
# 7/7 [==============================] - 0s 8ms/step - loss: 4.1361e-04 - val_loss: 4.8074e-04
# Epoch 148/500
# 7/7 [==============================] - 0s 10ms/step - loss: 4.0679e-04 - val_loss: 4.7839e-04
# Epoch 149/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.0565e-04 - val_loss: 4.8236e-04
# Epoch 150/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.0806e-04 - val_loss: 4.7532e-04
# Epoch 151/500
# 7/7 [==============================] - 0s 9ms/step - loss: 4.0256e-04 - val_loss: 4.7344e-04
# Epoch 152/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.9859e-04 - val_loss: 4.6724e-04
# Epoch 153/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.9558e-04 - val_loss: 4.6494e-04
# Epoch 154/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.9234e-04 - val_loss: 4.6351e-04
# Epoch 155/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.9170e-04 - val_loss: 4.6692e-04
# Epoch 156/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.9069e-04 - val_loss: 4.5881e-04
# Epoch 157/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.9925e-04 - val_loss: 4.6570e-04
# Epoch 158/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.8914e-04 - val_loss: 4.6697e-04
# Epoch 159/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.9117e-04 - val_loss: 4.5534e-04
# Epoch 160/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.8498e-04 - val_loss: 4.5417e-04
# Epoch 161/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.8199e-04 - val_loss: 4.5166e-04
# Epoch 162/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.7926e-04 - val_loss: 4.4838e-04
# Epoch 163/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7705e-04 - val_loss: 4.4610e-04
# Epoch 164/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7436e-04 - val_loss: 4.4510e-04
# Epoch 165/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.7447e-04 - val_loss: 4.4304e-04
# Epoch 166/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7550e-04 - val_loss: 4.4570e-04
# Epoch 167/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.7554e-04 - val_loss: 4.4702e-04
# Epoch 168/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7444e-04 - val_loss: 4.4400e-04
# Epoch 169/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7276e-04 - val_loss: 4.5231e-04
# Epoch 170/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7269e-04 - val_loss: 4.4486e-04
# Epoch 171/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.6881e-04 - val_loss: 4.3570e-04
# Epoch 172/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.6811e-04 - val_loss: 4.3434e-04
# Epoch 173/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.6357e-04 - val_loss: 4.3565e-04
# Epoch 174/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.6415e-04 - val_loss: 4.4834e-04
# Epoch 175/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7277e-04 - val_loss: 4.3248e-04
# Epoch 176/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7135e-04 - val_loss: 4.4732e-04
# Epoch 177/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.8498e-04 - val_loss: 4.7026e-04
# Epoch 178/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.7590e-04 - val_loss: 4.3352e-04
# Epoch 179/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.6707e-04 - val_loss: 4.4190e-04
# Epoch 180/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.7076e-04 - val_loss: 4.4400e-04
# Epoch 181/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.6485e-04 - val_loss: 4.2684e-04
# Epoch 182/500
# 7/7 [==============================] - 0s 12ms/step - loss: 3.5390e-04 - val_loss: 4.2121e-04
# Epoch 183/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.5198e-04 - val_loss: 4.2633e-04
# Epoch 184/500
# 7/7 [==============================] - 0s 11ms/step - loss: 3.5290e-04 - val_loss: 4.2994e-04
# Epoch 185/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.5012e-04 - val_loss: 4.1987e-04
# Epoch 186/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.4538e-04 - val_loss: 4.1419e-04
# Epoch 187/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4180e-04 - val_loss: 4.1108e-04
# Epoch 188/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4116e-04 - val_loss: 4.1611e-04
# Epoch 189/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.4074e-04 - val_loss: 4.0862e-04
# Epoch 190/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4129e-04 - val_loss: 4.0965e-04
# Epoch 191/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3835e-04 - val_loss: 4.0630e-04
# Epoch 192/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.3726e-04 - val_loss: 4.0725e-04
# Epoch 193/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3611e-04 - val_loss: 4.0501e-04
# Epoch 194/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.3537e-04 - val_loss: 4.1204e-04
# Epoch 195/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.4419e-04 - val_loss: 4.4418e-04
# Epoch 196/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.6600e-04 - val_loss: 4.1230e-04
# Epoch 197/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.6294e-04 - val_loss: 4.1602e-04
# Epoch 198/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.4569e-04 - val_loss: 4.2621e-04
# Epoch 199/500
# 7/7 [==============================] - 0s 12ms/step - loss: 3.4229e-04 - val_loss: 4.0589e-04
# Epoch 200/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3373e-04 - val_loss: 4.0512e-04
# Epoch 201/500
# 7/7 [==============================] - 0s 12ms/step - loss: 3.2967e-04 - val_loss: 3.9454e-04
# Epoch 202/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.2565e-04 - val_loss: 3.9518e-04
# Epoch 203/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.2318e-04 - val_loss: 3.9919e-04
# Epoch 204/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.2486e-04 - val_loss: 3.9692e-04
# Epoch 205/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.2332e-04 - val_loss: 3.9263e-04
# Epoch 206/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.2164e-04 - val_loss: 3.9201e-04
# Epoch 207/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.2090e-04 - val_loss: 3.9261e-04
# Epoch 208/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1954e-04 - val_loss: 3.9113e-04
# Epoch 209/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1694e-04 - val_loss: 3.8672e-04
# Epoch 210/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1429e-04 - val_loss: 3.8544e-04
# Epoch 211/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1286e-04 - val_loss: 3.8670e-04
# Epoch 212/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1319e-04 - val_loss: 3.8335e-04
# Epoch 213/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1221e-04 - val_loss: 3.8597e-04
# Epoch 214/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.1398e-04 - val_loss: 3.8274e-04
# Epoch 215/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1125e-04 - val_loss: 3.8399e-04
# Epoch 216/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1229e-04 - val_loss: 3.7989e-04
# Epoch 217/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0850e-04 - val_loss: 3.7945e-04
# Epoch 218/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0772e-04 - val_loss: 3.7735e-04
# Epoch 219/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0608e-04 - val_loss: 3.7622e-04
# Epoch 220/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0388e-04 - val_loss: 3.7464e-04
# Epoch 221/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0338e-04 - val_loss: 3.7620e-04
# Epoch 222/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0234e-04 - val_loss: 3.7550e-04
# Epoch 223/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0774e-04 - val_loss: 3.7831e-04
# Epoch 224/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0661e-04 - val_loss: 3.7659e-04
# Epoch 225/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0752e-04 - val_loss: 3.8138e-04
# Epoch 226/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0629e-04 - val_loss: 3.9500e-04
# Epoch 227/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.1118e-04 - val_loss: 3.7007e-04
# Epoch 228/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.0139e-04 - val_loss: 3.7239e-04
# Epoch 229/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0271e-04 - val_loss: 3.7857e-04
# Epoch 230/500
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0546e-04 - val_loss: 3.7272e-04
# Epoch 231/500
# 7/7 [==============================] - 0s 10ms/step - loss: 3.0627e-04 - val_loss: 3.6893e-04
# Epoch 232/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.9829e-04 - val_loss: 3.6679e-04
# Epoch 233/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9861e-04 - val_loss: 3.6887e-04
# Epoch 234/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9965e-04 - val_loss: 3.6636e-04
# Epoch 235/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.9716e-04 - val_loss: 3.7037e-04
# Epoch 236/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.9842e-04 - val_loss: 3.6791e-04
# Epoch 237/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0320e-04 - val_loss: 3.7980e-04
# Epoch 238/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0017e-04 - val_loss: 3.6342e-04
# Epoch 239/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.9685e-04 - val_loss: 3.7213e-04
# Epoch 240/500
# 7/7 [==============================] - 0s 9ms/step - loss: 3.0083e-04 - val_loss: 3.6513e-04
# Epoch 241/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.9355e-04 - val_loss: 3.6733e-04
# Epoch 242/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9032e-04 - val_loss: 3.6346e-04
# Epoch 243/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.8739e-04 - val_loss: 3.5791e-04
# Epoch 244/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.8479e-04 - val_loss: 3.5793e-04
# Epoch 245/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.8353e-04 - val_loss: 3.5724e-04
# Epoch 246/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.8780e-04 - val_loss: 3.5515e-04
# Epoch 247/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.8184e-04 - val_loss: 3.5209e-04
# Epoch 248/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.8032e-04 - val_loss: 3.5117e-04
# Epoch 249/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7893e-04 - val_loss: 3.5014e-04
# Epoch 250/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.7985e-04 - val_loss: 3.5858e-04
# Epoch 251/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.8153e-04 - val_loss: 3.5414e-04
# Epoch 252/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.8238e-04 - val_loss: 3.5207e-04
# Epoch 253/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7834e-04 - val_loss: 3.5048e-04
# Epoch 254/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7741e-04 - val_loss: 3.5361e-04
# Epoch 255/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7948e-04 - val_loss: 3.5404e-04
# Epoch 256/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.8843e-04 - val_loss: 3.6919e-04
# Epoch 257/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.8581e-04 - val_loss: 3.5308e-04
# Epoch 258/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.7532e-04 - val_loss: 3.4818e-04
# Epoch 259/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7370e-04 - val_loss: 3.4716e-04
# Epoch 260/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.7665e-04 - val_loss: 3.4905e-04
# Epoch 261/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.7372e-04 - val_loss: 3.4340e-04
# Epoch 262/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7218e-04 - val_loss: 3.4387e-04
# Epoch 263/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6904e-04 - val_loss: 3.4226e-04
# Epoch 264/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6911e-04 - val_loss: 3.4155e-04
# Epoch 265/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6907e-04 - val_loss: 3.4037e-04
# Epoch 266/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7013e-04 - val_loss: 3.5462e-04
# Epoch 267/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7176e-04 - val_loss: 3.5126e-04
# Epoch 268/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7332e-04 - val_loss: 3.4374e-04
# Epoch 269/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.6896e-04 - val_loss: 3.3884e-04
# Epoch 270/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6737e-04 - val_loss: 3.4258e-04
# Epoch 271/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6514e-04 - val_loss: 3.3855e-04
# Epoch 272/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.6326e-04 - val_loss: 3.3543e-04
# Epoch 273/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6106e-04 - val_loss: 3.3669e-04
# Epoch 274/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6215e-04 - val_loss: 3.3252e-04
# Epoch 275/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6027e-04 - val_loss: 3.3373e-04
# Epoch 276/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6184e-04 - val_loss: 3.3385e-04
# Epoch 277/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5893e-04 - val_loss: 3.3062e-04
# Epoch 278/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5704e-04 - val_loss: 3.2969e-04
# Epoch 279/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5587e-04 - val_loss: 3.3079e-04
# Epoch 280/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5561e-04 - val_loss: 3.2825e-04
# Epoch 281/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5412e-04 - val_loss: 3.2775e-04
# Epoch 282/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5376e-04 - val_loss: 3.2735e-04
# Epoch 283/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.5992e-04 - val_loss: 3.2955e-04
# Epoch 284/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5709e-04 - val_loss: 3.3856e-04
# Epoch 285/500
# 7/7 [==============================] - 0s 12ms/step - loss: 2.5752e-04 - val_loss: 3.2793e-04
# Epoch 286/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.6077e-04 - val_loss: 3.3715e-04
# Epoch 287/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.7033e-04 - val_loss: 3.4481e-04
# Epoch 288/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6178e-04 - val_loss: 3.2690e-04
# Epoch 289/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.5291e-04 - val_loss: 3.2206e-04
# Epoch 290/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5135e-04 - val_loss: 3.2466e-04
# Epoch 291/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4996e-04 - val_loss: 3.2703e-04
# Epoch 292/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.5181e-04 - val_loss: 3.2303e-04
# Epoch 293/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5503e-04 - val_loss: 3.2674e-04
# Epoch 294/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5405e-04 - val_loss: 3.1849e-04
# Epoch 295/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.4994e-04 - val_loss: 3.2917e-04
# Epoch 296/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5707e-04 - val_loss: 3.2917e-04
# Epoch 297/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.6290e-04 - val_loss: 3.2442e-04
# Epoch 298/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.5087e-04 - val_loss: 3.2071e-04
# Epoch 299/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4596e-04 - val_loss: 3.2085e-04
# Epoch 300/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4580e-04 - val_loss: 3.1809e-04
# Epoch 301/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4442e-04 - val_loss: 3.1837e-04
# Epoch 302/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4290e-04 - val_loss: 3.1432e-04
# Epoch 303/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4117e-04 - val_loss: 3.1420e-04
# Epoch 304/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4058e-04 - val_loss: 3.1307e-04
# Epoch 305/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4032e-04 - val_loss: 3.1344e-04
# Epoch 306/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3960e-04 - val_loss: 3.1503e-04
# Epoch 307/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3975e-04 - val_loss: 3.1241e-04
# Epoch 308/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.3769e-04 - val_loss: 3.1548e-04
# Epoch 309/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3933e-04 - val_loss: 3.1377e-04
# Epoch 310/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3762e-04 - val_loss: 3.1102e-04
# Epoch 311/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3647e-04 - val_loss: 3.0844e-04
# Epoch 312/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3641e-04 - val_loss: 3.0795e-04
# Epoch 313/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3437e-04 - val_loss: 3.0899e-04
# Epoch 314/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3493e-04 - val_loss: 3.1123e-04
# Epoch 315/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.3494e-04 - val_loss: 3.1399e-04
# Epoch 316/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4019e-04 - val_loss: 3.1476e-04
# Epoch 317/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3760e-04 - val_loss: 3.0701e-04
# Epoch 318/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3342e-04 - val_loss: 3.0484e-04
# Epoch 319/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3175e-04 - val_loss: 3.0805e-04
# Epoch 320/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3336e-04 - val_loss: 3.0664e-04
# Epoch 321/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3105e-04 - val_loss: 3.0622e-04
# Epoch 322/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3125e-04 - val_loss: 3.0403e-04
# Epoch 323/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2992e-04 - val_loss: 3.0453e-04
# Epoch 324/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3099e-04 - val_loss: 3.0724e-04
# Epoch 325/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3330e-04 - val_loss: 3.2202e-04
# Epoch 326/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.4330e-04 - val_loss: 3.1340e-04
# Epoch 327/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3691e-04 - val_loss: 3.0430e-04
# Epoch 328/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2968e-04 - val_loss: 3.0333e-04
# Epoch 329/500
# 7/7 [==============================] - 0s 8ms/step - loss: 2.2861e-04 - val_loss: 3.0740e-04
# Epoch 330/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3555e-04 - val_loss: 3.0465e-04
# Epoch 331/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.3107e-04 - val_loss: 2.9964e-04
# Epoch 332/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2507e-04 - val_loss: 2.9770e-04
# Epoch 333/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2352e-04 - val_loss: 2.9825e-04
# Epoch 334/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2408e-04 - val_loss: 2.9651e-04
# Epoch 335/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2248e-04 - val_loss: 2.9646e-04
# Epoch 336/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2280e-04 - val_loss: 2.9526e-04
# Epoch 337/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2168e-04 - val_loss: 2.9902e-04
# Epoch 338/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2345e-04 - val_loss: 2.9627e-04
# Epoch 339/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2043e-04 - val_loss: 2.9331e-04
# Epoch 340/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1944e-04 - val_loss: 2.9608e-04
# Epoch 341/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2244e-04 - val_loss: 2.9833e-04
# Epoch 342/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2526e-04 - val_loss: 3.0059e-04
# Epoch 343/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2371e-04 - val_loss: 2.9386e-04
# Epoch 344/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2176e-04 - val_loss: 2.9881e-04
# Epoch 345/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2272e-04 - val_loss: 2.9522e-04
# Epoch 346/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2034e-04 - val_loss: 2.9332e-04
# Epoch 347/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1869e-04 - val_loss: 2.9297e-04
# Epoch 348/500
# 7/7 [==============================] - 0s 13ms/step - loss: 2.1888e-04 - val_loss: 2.9231e-04
# Epoch 349/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1729e-04 - val_loss: 2.8991e-04
# Epoch 350/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1606e-04 - val_loss: 2.9693e-04
# Epoch 351/500
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2014e-04 - val_loss: 2.9794e-04
# Epoch 352/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2007e-04 - val_loss: 2.9852e-04
# Epoch 353/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2385e-04 - val_loss: 3.0054e-04
# Epoch 354/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2604e-04 - val_loss: 2.9172e-04
# Epoch 355/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2231e-04 - val_loss: 2.9099e-04
# Epoch 356/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1723e-04 - val_loss: 2.8757e-04
# Epoch 357/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1661e-04 - val_loss: 2.9574e-04
# Epoch 358/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1836e-04 - val_loss: 2.9618e-04
# Epoch 359/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.2283e-04 - val_loss: 2.9113e-04
# Epoch 360/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1715e-04 - val_loss: 3.0853e-04
# Epoch 361/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3245e-04 - val_loss: 3.0111e-04
# Epoch 362/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3056e-04 - val_loss: 2.9942e-04
# Epoch 363/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2086e-04 - val_loss: 2.9809e-04
# Epoch 364/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1722e-04 - val_loss: 2.8856e-04
# Epoch 365/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.1319e-04 - val_loss: 2.8534e-04
# Epoch 366/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1059e-04 - val_loss: 2.8275e-04
# Epoch 367/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0813e-04 - val_loss: 2.8196e-04
# Epoch 368/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0703e-04 - val_loss: 2.8106e-04
# Epoch 369/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0634e-04 - val_loss: 2.8125e-04
# Epoch 370/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0676e-04 - val_loss: 2.8084e-04
# Epoch 371/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.0629e-04 - val_loss: 2.8142e-04
# Epoch 372/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0579e-04 - val_loss: 2.7989e-04
# Epoch 373/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0509e-04 - val_loss: 2.7885e-04
# Epoch 374/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0411e-04 - val_loss: 2.7766e-04
# Epoch 375/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0316e-04 - val_loss: 2.7830e-04
# Epoch 376/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0349e-04 - val_loss: 2.8117e-04
# Epoch 377/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0744e-04 - val_loss: 2.8017e-04
# Epoch 378/500
# 7/7 [==============================] - 0s 13ms/step - loss: 2.0980e-04 - val_loss: 2.8111e-04
# Epoch 379/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1725e-04 - val_loss: 2.9603e-04
# Epoch 380/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2651e-04 - val_loss: 2.8083e-04
# Epoch 381/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1597e-04 - val_loss: 2.8668e-04
# Epoch 382/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0889e-04 - val_loss: 2.8148e-04
# Epoch 383/500
# 7/7 [==============================] - 0s 9ms/step - loss: 2.0657e-04 - val_loss: 2.8217e-04
# Epoch 384/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0406e-04 - val_loss: 2.7698e-04
# Epoch 385/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0102e-04 - val_loss: 2.7694e-04
# Epoch 386/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9999e-04 - val_loss: 2.7474e-04
# Epoch 387/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9891e-04 - val_loss: 2.7461e-04
# Epoch 388/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9999e-04 - val_loss: 2.7824e-04
# Epoch 389/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0638e-04 - val_loss: 2.7857e-04
# Epoch 390/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1831e-04 - val_loss: 3.3241e-04
# Epoch 391/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.2681e-04 - val_loss: 2.9884e-04
# Epoch 392/500
# 7/7 [==============================] - 0s 11ms/step - loss: 2.1516e-04 - val_loss: 2.8561e-04
# Epoch 393/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0663e-04 - val_loss: 2.7767e-04
# Epoch 394/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0128e-04 - val_loss: 2.7296e-04
# Epoch 395/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9768e-04 - val_loss: 2.7240e-04
# Epoch 396/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9764e-04 - val_loss: 2.7155e-04
# Epoch 397/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9558e-04 - val_loss: 2.7182e-04
# Epoch 398/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9627e-04 - val_loss: 2.7083e-04
# Epoch 399/500
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0019e-04 - val_loss: 2.7417e-04
# Epoch 400/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9736e-04 - val_loss: 2.7543e-04
# Epoch 401/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9733e-04 - val_loss: 2.7112e-04
# Epoch 402/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9523e-04 - val_loss: 2.6942e-04
# Epoch 403/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9418e-04 - val_loss: 2.6907e-04
# Epoch 404/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9303e-04 - val_loss: 2.6699e-04
# Epoch 405/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9289e-04 - val_loss: 2.6819e-04
# Epoch 406/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9211e-04 - val_loss: 2.6733e-04
# Epoch 407/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9156e-04 - val_loss: 2.6712e-04
# Epoch 408/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9177e-04 - val_loss: 2.6603e-04
# Epoch 409/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.9175e-04 - val_loss: 2.6933e-04
# Epoch 410/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9494e-04 - val_loss: 2.8074e-04
# Epoch 411/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9899e-04 - val_loss: 2.7023e-04
# Epoch 412/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9424e-04 - val_loss: 2.7182e-04
# Epoch 413/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9464e-04 - val_loss: 2.6951e-04
# Epoch 414/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9335e-04 - val_loss: 2.6667e-04
# Epoch 415/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9112e-04 - val_loss: 2.6703e-04
# Epoch 416/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8968e-04 - val_loss: 2.6483e-04
# Epoch 417/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8820e-04 - val_loss: 2.6436e-04
# Epoch 418/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9151e-04 - val_loss: 2.6829e-04
# Epoch 419/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9458e-04 - val_loss: 2.6904e-04
# Epoch 420/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9214e-04 - val_loss: 2.6768e-04
# Epoch 421/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9135e-04 - val_loss: 2.6519e-04
# Epoch 422/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8958e-04 - val_loss: 2.6441e-04
# Epoch 423/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8968e-04 - val_loss: 2.6577e-04
# Epoch 424/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8768e-04 - val_loss: 2.6601e-04
# Epoch 425/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.8708e-04 - val_loss: 2.6230e-04
# Epoch 426/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8552e-04 - val_loss: 2.6072e-04
# Epoch 427/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8444e-04 - val_loss: 2.6193e-04
# Epoch 428/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8641e-04 - val_loss: 2.6200e-04
# Epoch 429/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8699e-04 - val_loss: 2.6290e-04
# Epoch 430/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8698e-04 - val_loss: 2.6848e-04
# Epoch 431/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8893e-04 - val_loss: 2.6327e-04
# Epoch 432/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8861e-04 - val_loss: 2.6347e-04
# Epoch 433/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8620e-04 - val_loss: 2.6301e-04
# Epoch 434/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8647e-04 - val_loss: 2.6032e-04
# Epoch 435/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8512e-04 - val_loss: 2.6478e-04
# Epoch 436/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8648e-04 - val_loss: 2.5932e-04
# Epoch 437/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8515e-04 - val_loss: 2.6642e-04
# Epoch 438/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9841e-04 - val_loss: 2.6506e-04
# Epoch 439/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.9010e-04 - val_loss: 2.6527e-04
# Epoch 440/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9021e-04 - val_loss: 2.6508e-04
# Epoch 441/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8789e-04 - val_loss: 2.6919e-04
# Epoch 442/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8657e-04 - val_loss: 2.6781e-04
# Epoch 443/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9218e-04 - val_loss: 2.6469e-04
# Epoch 444/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8693e-04 - val_loss: 2.5809e-04
# Epoch 445/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8227e-04 - val_loss: 2.5754e-04
# Epoch 446/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8043e-04 - val_loss: 2.5579e-04
# Epoch 447/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7808e-04 - val_loss: 2.5406e-04
# Epoch 448/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7808e-04 - val_loss: 2.6136e-04
# Epoch 449/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8587e-04 - val_loss: 2.6549e-04
# Epoch 450/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8389e-04 - val_loss: 2.5838e-04
# Epoch 451/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8196e-04 - val_loss: 2.5802e-04
# Epoch 452/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7880e-04 - val_loss: 2.5484e-04
# Epoch 453/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.7781e-04 - val_loss: 2.5335e-04
# Epoch 454/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.7625e-04 - val_loss: 2.5332e-04
# Epoch 455/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7758e-04 - val_loss: 2.5626e-04
# Epoch 456/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7850e-04 - val_loss: 2.5334e-04
# Epoch 457/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.7807e-04 - val_loss: 2.5654e-04
# Epoch 458/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7963e-04 - val_loss: 2.5587e-04
# Epoch 459/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8006e-04 - val_loss: 2.5494e-04
# Epoch 460/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7850e-04 - val_loss: 2.5433e-04
# Epoch 461/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7752e-04 - val_loss: 2.5565e-04
# Epoch 462/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7667e-04 - val_loss: 2.6043e-04
# Epoch 463/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8164e-04 - val_loss: 2.5414e-04
# Epoch 464/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8238e-04 - val_loss: 2.5789e-04
# Epoch 465/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8754e-04 - val_loss: 2.6155e-04
# Epoch 466/500
# 7/7 [==============================] - 0s 8ms/step - loss: 1.8211e-04 - val_loss: 2.5520e-04
# Epoch 467/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.7654e-04 - val_loss: 2.4985e-04
# Epoch 468/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7343e-04 - val_loss: 2.6073e-04
# Epoch 469/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7867e-04 - val_loss: 2.5705e-04
# Epoch 470/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7563e-04 - val_loss: 2.5093e-04
# Epoch 471/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7254e-04 - val_loss: 2.4825e-04
# Epoch 472/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7213e-04 - val_loss: 2.5062e-04
# Epoch 473/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.7347e-04 - val_loss: 2.5371e-04
# Epoch 474/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7655e-04 - val_loss: 2.5165e-04
# Epoch 475/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7488e-04 - val_loss: 2.5163e-04
# Epoch 476/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7325e-04 - val_loss: 2.4964e-04
# Epoch 477/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7435e-04 - val_loss: 2.5064e-04
# Epoch 478/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7335e-04 - val_loss: 2.4940e-04
# Epoch 479/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7161e-04 - val_loss: 2.5355e-04
# Epoch 480/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7435e-04 - val_loss: 2.4537e-04
# Epoch 481/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.7329e-04 - val_loss: 2.4660e-04
# Epoch 482/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6990e-04 - val_loss: 2.4773e-04
# Epoch 483/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7048e-04 - val_loss: 2.4528e-04
# Epoch 484/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7316e-04 - val_loss: 2.5142e-04
# Epoch 485/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7344e-04 - val_loss: 2.4678e-04
# Epoch 486/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7131e-04 - val_loss: 2.4872e-04
# Epoch 487/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6940e-04 - val_loss: 2.4694e-04
# Epoch 488/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6808e-04 - val_loss: 2.4512e-04
# Epoch 489/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.6682e-04 - val_loss: 2.4719e-04
# Epoch 490/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6725e-04 - val_loss: 2.4527e-04
# Epoch 491/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.6755e-04 - val_loss: 2.4593e-04
# Epoch 492/500
# 7/7 [==============================] - 0s 12ms/step - loss: 1.6895e-04 - val_loss: 2.6196e-04
# Epoch 493/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7420e-04 - val_loss: 2.5175e-04
# Epoch 494/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.6986e-04 - val_loss: 2.4422e-04
# Epoch 495/500
# 7/7 [==============================] - 0s 14ms/step - loss: 1.6652e-04 - val_loss: 2.4246e-04
# Epoch 496/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6595e-04 - val_loss: 2.4791e-04
# Epoch 497/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7143e-04 - val_loss: 2.7909e-04
# Epoch 498/500
# 7/7 [==============================] - 0s 11ms/step - loss: 1.8343e-04 - val_loss: 2.4773e-04
# Epoch 499/500
# 7/7 [==============================] - 0s 9ms/step - loss: 1.7649e-04 - val_loss: 2.4934e-04
# Epoch 500/500
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7075e-04 - val_loss: 2.4710e-04
# CPU times: user 36.7 s, sys: 2.95 s, total: 39.6 s
# Wall time: 49.5 s

# %%
# plot learning curves
plot_learning_curves(history_1D.history["loss"])

# %%
# plot predictions function
def plot_comparison_1D(start_idx, length=100, train=True):
    """
    Plot the predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if train:
        # Use training-data.
        x = X_train_scaled
        y_true = y_train
    else:
        # Use test-data.
        x = X_test_scaled
        y_true = y_test
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    x = np.expand_dims(x, axis=0)
    # x = x.reshape((1, x.shape[0], x.shape[1]))

    # Use the model to predict the output-signals.
    y_pred = model_1D.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
    y_pred_rescaled = y_scaler.inverse_transform(y_pred)
    
    # For each output-signal.
    for signal in range(len(target)):
        # Get the output-signal predicted by the model.
        signal_pred = y_pred_rescaled[:]
        
        # Get the true output-signal from the data-set.
        signal_true = y_true[:]

        # Make the plotting-canvas bigger.
        plt.figure(figsize=(15,5))
        
        # Plot and compare the two signals.
        plt.plot(signal_true, label='true')
        plt.plot(signal_pred, label='pred')
        
        # Plot grey box for warmup-period.
        p = plt.axvspan(0, 5, facecolor='black', alpha=0.15)
        
        # Plot labels etc.
        plt.ylabel(target[signal])
        plt.legend()
        plt.show()
        # print sklearn mean squared error
        print('MSE:', np.sqrt(mean_squared_error(signal_true, signal_pred)))

# %%
y_pred = model_1D.predict(X_test_1D)
plt.figure(figsize=(15,5))
plt.plot(y_pred[5,:,0], label='pred')
plt.plot(X_test_1D[5,:,0], label = 'true')
p = plt.axvspan(0, 5, facecolor='black', alpha=0.15)
plt.legend()
plt.show()
print('MSE:', np.sqrt(mean_squared_error(X_test_1D[5,:,0], y_pred[5,:,0]))*100)
# Out:
# MSE: 14.543768763542175

# %%
y_pred = model_1D.predict(X_train_1D)
plt.figure(figsize=(15,5))
plt.plot(y_pred[5,:,0], label='pred')
plt.plot(X_train_1D[5,:,0], label = 'true')
p = plt.axvspan(0, 5, facecolor='black', alpha=0.15)
plt.legend()
plt.show()
print('MSE:', np.sqrt(mean_squared_error(X_train_1D[5,:,0], y_pred[5,:,0]))*100)
# Out:
# MSE: 6.861748546361923
